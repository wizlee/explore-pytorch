# %% [markdown]
# # Module 4: Working with Text Data
#
# Preprocessing our data is very important.
#
# We may encounter data that is not clean. As we can see in DataFrame below:
# - First name and last name are separated by a comma.
# - Employee Annual Salary has a dollar ( $ ) sign, which means we cannot do mathematical operation on it.

# %%
import pandas as pd
df = pd.read_csv("data/chicago.csv")
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null object
# Employee Annual Salary    32062 non-null object
# dtypes: object(4)
# memory usage: 1002.0+ KB

# %% [markdown]
# In Department column, we have 35 categories. It is much better to change the column type to **category** as we have 32,063 rows of data. Rather than having 32,063 strings, we can classify them into 35 categories.
#
# You can see that the memory usage decreases from 1002KB to 784.4KB. This may speed up our operation so much more.

# %%
df["Department"].nunique()
# Out:
# 35

# %%
df["Department"] = df["Department"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(1), object(3)
# memory usage: 784.4+ KB

# %% [markdown]
# ### Remove null values

# %%
df.tail()
# Out:
#                       Name           Position Title Department  \
# 32058   ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
# 32062                  NaN                      NaN        NaN
#
#       Employee Annual Salary
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00
# 32062                    NaN

# %%
df.dropna(how="all", inplace=True)
df.tail()
# Out:
#                       Name                  Position Title        Department  \
# 32057  ZYGADLO,  MICHAEL J  FRM OF MACHINISTS - AUTOMOTIVE  GENERAL SERVICES
# 32058   ZYGOWICZ,  PETER J                  POLICE OFFICER            POLICE
# 32059    ZYMANTAS,  MARK E                  POLICE OFFICER            POLICE
# 32060  ZYRKOWSKI,  CARLO E                  POLICE OFFICER            POLICE
# 32061  ZYSKOWSKI,  DARIUSZ         CHIEF DATA BASE ANALYST              DoIT
#
#       Employee Annual Salary
# 32057              $99528.00
# 32058              $87384.00
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %% [markdown]
# ### Python built-in function : lower(), upper(), title() , len()
#
# - lower() : returns the string in lowercase.
# - upper() : returns a copy of the string in uppercase.
# - title() : convert the first character in each word to uppercase and remaining characters to lowercase in string
# - len() : calculate the length of string/ list/ etc. (In string, space also counts as a character)

# %%
"HELLO WORLD".lower()
# Out:
# 'hello world'

# %%
"hello world".upper()
# Out:
# 'HELLO WORLD'

# %%
"hello world".title()
# Out:
# 'Hello World'

# %%
len("HELLO WORLD")
# Out:
# 11

# %% [markdown]
# These functions allow us to change the format in Name column into something more readable.

# %%
df["Name"] = df["Name"].str.title()
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          WATER RATE TAKER       WATER MGMNT
# 1    Aaron,  Jeffery M            POLICE OFFICER            POLICE
# 2       Aaron,  Karina            POLICE OFFICER            POLICE
# 3  Aaron,  Kimberlei R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  Abad Jr,  Vicente M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# The same goes for Position Title column and Department column.

# %%
df["Position Title"] = df["Position Title"].str.title()
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker       WATER MGMNT
# 1    Aaron,  Jeffery M            Police Officer            POLICE
# 2       Aaron,  Karina            Police Officer            POLICE
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  GENERAL SERVICES
# 4  Abad Jr,  Vicente M         Civil Engineer Iv       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
df["Department"] = df["Department"].str.title()
df.head()
# Out:
#                   Name            Position Title        Department  \
# 0      Aaron,  Elvia J          Water Rate Taker       Water Mgmnt
# 1    Aaron,  Jeffery M            Police Officer            Police
# 2       Aaron,  Karina            Police Officer            Police
# 3  Aaron,  Kimberlei R  Chief Contract Expediter  General Services
# 4  Abad Jr,  Vicente M         Civil Engineer Iv       Water Mgmnt
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %% [markdown]
# ### replace() method
#
# The function is used to replace a string, regex, list, dictionary, series, or number.
#
# In the Department column, "Management“ is shortened to "Mgmnt“ while in the Employee Annual Salary column, there is dollar sign ( $ ) in each values. These data can be cleaned using replace() method.
#
# Firstly, we have to understand how the method works. The first argument is the pattern that we want to replace. The second argument is what we want it to be replaced with.

# %%
"Hello World".replace("l", "!")
# Out:
# 'He!!o Wor!d'

# %%
df["Department"] = df["Department"].str.replace("Mgmnt", "Management")
df.head(3)
# Out:
#                 Name    Position Title        Department  \
# 0    Aaron,  Elvia J  Water Rate Taker  Water Management
# 1  Aaron,  Jeffery M    Police Officer            Police
# 2     Aaron,  Karina    Police Officer            Police
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00

# %% [markdown]
# Let's remove the dollar sign in Employee Annual Salary column as well and change the data type to float.

# %%
df["Employee Annual Salary"] = df["Employee Annual Salary"].str.replace("$", "").astype(float)
df.head(3)
# Out:
#                 Name    Position Title        Department  \
# 0    Aaron,  Elvia J  Water Rate Taker  Water Management
# 1  Aaron,  Jeffery M    Police Officer            Police
# 2     Aaron,  Karina    Police Officer            Police
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0

# %% [markdown]
# Now, we can do mathematical operations on that column. We can get the average annual salary which is 80,204.

# %%
df["Employee Annual Salary"].mean()
# Out:
# 80204.178633899

# %% [markdown]
# 28443          Thomas,  Howard                               Water Rate Taker
# 28574       Threatt,  Denise R                        Water Quality Inspector
# 28602        Tignor,  Darryl B                               Water Rate Taker
# 28955   Travis Cook,  Leslie R                               Water Rate Taker
# 29584         Velazquez,  John                               Water Rate Taker
# 29669           Verma,  Anupam           Managing Engineer - Water Management
# 30239      Washington,  Joseph                              Water Chemist Iii
# 30544          West,  Thomas R                   Gen Supt Of Water Management
# 30991       Williams,  Matthew             Foreman Of Water Pipe Construction
# 31405     Woodridge,  Robert L             Foreman Of Water Pipe Construction
#
#              Department  Employee Annual Salary
# 0      Water Management                 90744.0
# 554    Water Management                102440.0
# 671    Water Management                 82044.0
# 685    Water Management                109272.0
# 702    Water Management                102440.0
# 1054   Water Management                 82044.0
# 1079   Water Management                 82044.0
# 1181   Water Management                 53172.0
# 1285   Water Management                 82576.0
# 2400   Water Management                 78948.0
# 2586   Water Management                 82044.0
# 2745   Water Management                 53172.0
# 3143   Water Management                 82728.0
# 3246   Water Management                 66780.0
# 3456   Water Management                 90744.0
# 3626   Water Management                 90744.0
# 3663   Water Management                102440.0
# 4889   Water Management                 82576.0
# 5506   Water Management                 82044.0
# 6337   Water Management                 82576.0
# 6421   Water Management                119208.0
# 6564   Water Management                102440.0
# 6954   Water Management                 90744.0
# 7356   Water Management                102440.0
# 7463   Water Management                102440.0
# 7641   Water Management                 90744.0
# 7650   Water Management                 82576.0
# 8092   Water Management                 78948.0
# 8660   Water Management                102440.0
# 9325   Water Management                 96840.0
# ...                 ...                     ...
# 23187  Water Management                 70152.0
# 24003  Water Management                 78948.0
# 24178  Water Management                 66780.0
# 24266  Water Management                 90744.0
# 24422  Water Management                 78948.0
# 24501  Water Management                 90744.0
# 24945  Water Management                 65172.0
# 25055  Water Management                 90744.0
# 25233  Water Management                109008.0
# 25260  Water Management                118656.0
# 26372  Water Management                 89676.0
# 26519  Water Management                 90744.0
# 26625  Water Management                 90744.0
# 26871  Water Management                 90744.0
# 27015  Water Management                 90744.0
# 27368  Water Management                102440.0
# 27537  Water Management                102440.0
# 27635  Water Management                 82044.0
# 27755  Water Management                 82576.0
# 28185  Water Management                 82728.0
# 28443  Water Management                 78948.0
# 28574  Water Management                 62004.0
# 28602  Water Management                 78948.0
# 28955  Water Management                 78948.0
# 29584  Water Management                 78948.0
# 29669  Water Management                111192.0
# 30239  Water Management                 89676.0
# 30544  Water Management                115704.0
# 30991  Water Management                102440.0
# 31405  Water Management                102440.0
#
# [111 rows x 4 columns]

# %% [markdown]
# We can identify specialists by using **endswith()** method. Here, we have 100 specialists from different departments

# %%
mask = df["Position Title"].str.endswith("Specialist")
df[mask]
# Out:
#                           Name  \
# 308           Alarcon,  Luis J
# 422           Allain,  Carolyn
# 705        Anderson,  Edward M
# 1163           Ayala Jr,  Juan
# 1558       Barrett,  Barbara J
# 1869        Beltran,  Mauricio
# 2095        Biggane,  Thomas M
# 2319            Bobba,  Mahita
# 2519      Boston,  Nathaniel K
# 2678           Bradley,  Jeena
# 4109            Carter,  Alice
# 4479             Chan,  Joseph
# 5043         Coco,  Michelle T
# 5307          Condon,  Kristin
# 5633        Cortes,  Jezieel T
# 0                     90744.0
# 671                   82044.0
# 1054                  82044.0
# 1079                  82044.0
# 1181                  53172.0
# 1285                  82576.0
# 2400                  78948.0
# 2586                  82044.0
# 2745                  53172.0
# 3143                  82728.0
# 3246                  66780.0
# 3456                  90744.0
# 3626                  90744.0
# 4889                  82576.0
# 5506                  82044.0
# 6337                  82576.0
# 6954                  90744.0
# 7641                  90744.0
# 7650                  82576.0
# 8092                  78948.0
# 10170                 82576.0
# 10457                 82576.0
# 10707                 82576.0
# 11857                 78948.0
# 12408                 82576.0
# 12487                104748.0
# 12594                 53172.0
# 12781                 66780.0
# 13361                 89676.0
# 13476                 82576.0
# ...                       ...
# 20936                 82576.0
# 20962                 82044.0
# 21078                 82576.0
# 21212                 86580.0
# 21788                 70152.0
# 22384                 82576.0
# 22916                 82576.0
# 23102                114552.0
# 23187                 70152.0
# 24003                 78948.0
# 24178                 66780.0
# 24266                 90744.0
# 24422                 78948.0
# 24501                 90744.0
# 24945                 65172.0
# 25055                 90744.0
# 26372                 89676.0
# 26519                 90744.0
# 26625                 90744.0
# 26871                 90744.0
# 27015                 90744.0
# 27635                 82044.0
# 27755                 82576.0
# 28185                 82728.0
# 28443                 78948.0
# 28574                 62004.0
# 28602                 78948.0
# 28955                 78948.0
# 29584                 78948.0
# 30239                 89676.0
#
# [75 rows x 4 columns]

# %% [markdown]
# ### strip() , lstrip() , rstrip()
#
# Strip means removing white space at the start or end of a string.
#
# **lstrip()** stands for left strip. It will only remove white space on the left. On the other hand, **rstrip()** will only remove white space on the right.
#
# These methods are very handy to clean unneeded spaces in the data. Sometimes users tend to make mistakes on input.

# %%
"         Hello Word   ".strip()
# Out:
# 'Hello Word'

# %%
"         Hello Word   ".lstrip()
# Out:
# 'Hello Word   '

# %%
"         Hello Word   ".rstrip()
# Out:
# '         Hello Word'

# %%
df["Name"] = df["Name"].str.strip()
df["Name"].head()
# Out:
# 0        Aaron,  Elvia J
# 1      Aaron,  Jeffery M
# 2         Aaron,  Karina
# 3    Aaron,  Kimberlei R
# 4    Abad Jr,  Vicente M
# Name: Name, dtype: object

# %% [markdown]
# ### Spilit String by Character using .str.split() method
#
# Split string by a character using **.str.split()** method. It will split strings around given separator/delimiter.
#
# The split() method will divide the string based on the separator that we specify. In the example, the separator is a space ( " " )

# %%
"My name is Ali bin Abu".split(" ")
# Out:
# ['My', 'name', 'is', 'Ali', 'bin', 'Abu']

# %% [markdown]
# We can separate the Last name and first name in Name column.

# %%
lastName =  df["Name"].str.split(",").str.get(0).str.strip()
lastName
# Out:
# 0                 Aaron
# 1                 Aaron
# 2                 Aaron
# 3                 Aaron
# 4               Abad Jr
# 5                Abarca
# 6                Abarca
# 7               Abascal
# 8                Abbasi
# 9            Abbatacola
# 10          Abbatemarco
# 11               Abbate
# 12               Abbott
# 13               Abbott
# 14           Abbruzzese
# 15             Abdallah
# 16            Abdelhadi
# 17           Abdellatif
# 18          Abdelmajeid
# 19        Abdollahzadeh
# 20          Abdul-Karim
# 21             Abdullah
# 22             Abdullah
# 23             Abdullah
# 24             Abdullah
# 25          Abdulsattar
# 26         Abdul-Shakur
# 27           Abdulwahab
# 28              Abejero
# 29       Abercrombie Iv
#               ...
# 32032         Zuniga Jr
# 32033            Zuniga
# 32034            Zuniga
# 32035            Zuniga
# 32036            Zuniga
# 32037            Zuniga
# 32038              Zuno
# 32039             Zupan
# 32040          Zupancic
# 32041          Zurawski
# 32042          Zurawski
# 32043          Zurawski
# 32044          Zurawski
# 32045             Zurek
# 32046             Zurek
# 32047            Zurita
# 32048            Zvanja
# 32049      Zwarycz Mann
# 32050           Zwarycz
# 32051          Zwiesler
# 32052              Zwit
# 32053           Zwolfer
# 32054              Zych
# 32055             Zydek
# 32056           Zygadlo
# 32057           Zygadlo
# 32058          Zygowicz
# 32059          Zymantas
# 32060         Zyrkowski
# 32061         Zyskowski
# Name: Name, Length: 32062, dtype: object

# %%
firstName =  df["Name"].str.split(",").str.get(1).str.strip().str.split(" ").str.get(0)
firstName.head(20)
# Out:
# 0           Elvia
# 1         Jeffery
# 2          Karina
# 3       Kimberlei
# 4         Vicente
# 5          Anabel
# 6        Emmanuel
# 7           Reece
# 8     Christopher
# 9          Robert
# 10          James
# 11          Terry
# 12          Betty
# 13         Lynise
# 14        William
# 15           Zaid
# 16      Abdalmahd
# 17           Aref
# 18           Aziz
# 19            Ali
# Name: Name, dtype: object

# %% [markdown]
# After we have extracted the First Name and Last Name, we can add a new column into the DataFrame using the insert() method.

# %%
df.insert(0,column = "First Name" , value = firstName)
df.insert(1,column = "Last Name" ,value = lastName)
df.head()
# Out:
#   First Name Last Name                 Name            Position Title  \
# 0      Elvia     Aaron      Aaron,  Elvia J          Water Rate Taker
# 1    Jeffery     Aaron    Aaron,  Jeffery M            Police Officer
# 2     Karina     Aaron       Aaron,  Karina            Police Officer
# 3  Kimberlei     Aaron  Aaron,  Kimberlei R  Chief Contract Expediter
# 4    Vicente   Abad Jr  Abad Jr,  Vicente M         Civil Engineer Iv
#
#          Department  Employee Annual Salary
# 0  Water Management                 90744.0
# 1            Police                 84450.0
# 2            Police                 84450.0
# 3  General Services                 89880.0
# 4  Water Management                106836.0

# %% [markdown]
# Once the new columns are added, we may drop the Name column to avoid redundancy.

# %%
# df.drop(labels= "Name" , axis = 1, inplace=True)
# df.head()

# %%
df["First Name"].value_counts().head()
# Out:
# Michael    1153
# John        899
# James       676
# Robert      622
# Joseph      537
# Name: First Name, dtype: int64

# %% [markdown]
# In **split()**, the **expand parameter** will expand the split strings into separate columns.

# %%
df["Name"].str.split(",", expand=True).head()
# Out:
#          0              1
# 0    Aaron        Elvia J
# 1    Aaron      Jeffery M
# 2    Aaron         Karina
# 3    Aaron    Kimberlei R
# 4  Abad Jr      Vicente M

# %% [markdown]
# **split()** has **n parameter** which we can use to decide how many occurrences to split. The example shows that we are splitting strings around a space. Since, we give argument of 1 to the n parameter, it will only split the strings around the first space it finds.

# %%
df["Position Title"].str.split(" ", expand=True, n = 1).head()
# Out:
#         0                   1
# 0   Water          Rate Taker
# 1  Police             Officer
# 2  Police             Officer
# 3   Chief  Contract Expediter
# 4   Civil         Engineer Iv

# %% [markdown]
# ## Regular Expression (ReGex) with Pandas
#
# Regex is a powerful library to search for word(s) in the string. It can also find sequence of characters/words.
#
# Example: Validating a password format. When we want to create a new password, there are some requirements to be fulfilled like it should include uppercase, lowercase, numbers, and unique character.
#
# Python has a library specifically for regex.
#
# Python ReGex Cheat Sheet : https://www.cheatography.com/mutanclan/cheat-sheets/python-regular-expression-regex/

# %%
import re

# %% [markdown]
# In **re module**, there is a few common libraries used.
#
# **match()** function returns a matched object if the text matches the pattern <br>
# **search()** function checks for a match anywhere in the string. <br>
# **compile()** Compiles a regular expression pattern into a regular expression object. <br>
# **findall()** Return all non-overlapping matches of pattern in string, as a list of strings
#
# Tips: When you need to use an expression several times in a single program, using the compile() function to save the resulting regular expression object for reuse is more efficient.

# %% [markdown]
# **dot (.) : Match any character except newline**

# %%
text = "Amin Hakim"
pattern = r"Ami."

pattern = re.compile(pattern)

result = pattern.search(text)
print(result.group())
# Out:
# Amin

# %%
text2 = "Amir Haiqal"

pattern2 = pattern.search(text2)
print(pattern2.group())
# Out:
# Amir

# %% [markdown]
# **bracket ([]) : Match anything in the bracket.**

# %%
text3 = "I'm 21 years old"

pattern = re.compile("[1-9]")
result = pattern.search(text3)
print(bool(result))
# Out:
# True

# %% [markdown]
# In Pandas, we can use regex to search the pattern that we want in the text. As I mentioned before, we can include regex in **str.contains() function**.
#
# For example, we want to search for Position Title which has a digit in it.

# %%
df.loc[df["Position Title"].str.contains("[1-9]")].head(10)
# Out:
#      First Name     Last Name                    Name  \
# 275        Mark         Akana          Akana,  Mark S
# 892     Gilbert          Arce          Arce,  Gilbert
# 1151     Rhonda         Avina        Avina,  Rhonda S
# 1233      Gayla       Baggett       Baggett,  Gayla D
# 1934    Timothy         Beran         Beran,  Timothy
# 2170     Eunice  Bishop Abren   Bishop Abren,  Eunice
# 2751    Michael    Bransfield  Bransfield,  Michael P
# 3521     Sheila        Butler         Butler,  Sheila
# 3561      James         Byrne         Byrne,  James T
# 3764      Brian      Campbell      Campbell,  Brian P
#
#                              Position Title Department  Employee Annual Salary
# 275   Police Officer/Explsv Detect K9 Hndlr     Police                 95178.0
# 892   Police Officer/Explsv Detect K9 Hndlr     Police                 98016.0
# 1151        Communications Operator I - 311       Oemc                 59184.0
# 1233        Communications Operator I - 311       Oemc                 62004.0
# 1934  Police Officer/Explsv Detect K9 Hndlr     Police                 91752.0
# 2170        Communications Operator I - 311       Oemc                 68028.0
# 2751  Police Officer/Explsv Detect K9 Hndlr     Police                 98016.0
# 3521  Police Officer/Explsv Detect K9 Hndlr     Police                 95178.0
# 3561  Police Officer/Explsv Detect K9 Hndlr     Police                 98016.0
# 3764  Police Officer/Explsv Detect K9 Hndlr     Police                 95178.0

# %% [markdown]
# We can go very specific with additional regex. Say, we want to search for Position Title, which contains the word, "Police" as well as number(s).
#
# - **dot (.)** : Match any character except newline
# - **star ( * )** : Zero or more occurrences
# - **bracket ([ ])** : Match with anything in the bracket.

# %%
df.loc[df["Position Title"].str.contains("Police.*[1-9]")].head(10)
# Out:
#      First Name   Last Name                    Name  \
# 275        Mark       Akana          Akana,  Mark S
# 892     Gilbert        Arce          Arce,  Gilbert
# 1934    Timothy       Beran         Beran,  Timothy
# 2751    Michael  Bransfield  Bransfield,  Michael P
# 3521     Sheila      Butler         Butler,  Sheila
# 3561      James       Byrne         Byrne,  James T
# 3764      Brian    Campbell      Campbell,  Brian P
# 5593    Rodolfo    Coronado    Coronado,  Rodolfo E
# 6344       Paul   Davenport      Davenport,  Paul B
# 6937     Joshua        Diaz           Diaz,  Joshua
#
#                              Position Title Department  Employee Annual Salary
# 275   Police Officer/Explsv Detect K9 Hndlr     Police                 95178.0
# 892   Police Officer/Explsv Detect K9 Hndlr     Police                 98016.0
# 1934  Police Officer/Explsv Detect K9 Hndlr     Police                 91752.0
# 2751  Police Officer/Explsv Detect K9 Hndlr     Police                 98016.0
# 3521  Police Officer/Explsv Detect K9 Hndlr     Police                 95178.0
# 3561  Police Officer/Explsv Detect K9 Hndlr     Police                 98016.0
# 3764  Police Officer/Explsv Detect K9 Hndlr     Police                 95178.0
# 5593  Police Officer/Explsv Detect K9 Hndlr     Police                 95178.0
# 6344  Police Officer/Explsv Detect K9 Hndlr     Police                 95178.0
# 6937  Police Officer/Explsv Detect K9 Hndlr     Police                 88656.0

# %% [markdown]
# Let's search for Position Title that starts with **Water** and ends with **Taker**
#
# - **^** : Start of string
# - **Bracket []** : Match anything in the bracket. Eg: [Ww] means match any which have w or W
# -  **Dot (.)** : Match any single character except the newline character.
# - **star ( * )** : Zero or more occurrences.
# - **\b** : Word boundary. Spaces between word.

# %%
df.loc[df["Position Title"].str.contains("^[wW]ater.*Taker")].head(15)
# Out:
#       First Name  Last Name                 Name    Position Title  \
# 0          Elvia      Aaron      Aaron,  Elvia J  Water Rate Taker
# 2400       Brian     Bolton     Bolton,  Brian E  Water Rate Taker
# 3143      Sharon      Brown     Brown,  Sharon L  Water Rate Taker
# 3456        Carl       Burt        Burt,  Carl S  Water Rate Taker
# 3626     Ophelia       Cage       Cage,  Ophelia  Water Rate Taker
# 6954       Oscar       Diaz       Diaz,  Oscar A  Water Rate Taker
# 7641    Patricia     Durant  Durant,  Patricia B  Water Rate Taker
# 8092     Rodolfo   Espinosa   Espinosa,  Rodolfo  Water Rate Taker
# 11857        Lee    Hedrick      Hedrick,  Lee A  Water Rate Taker
# 13729     Curtis    Johnson   Johnson,  Curtis V  Water Rate Taker
# 14771     Inayat       Khan      Khan,  Inayat U  Water Rate Taker
# 15215    Anthony  Kordowski  Kordowski,  Anthony  Water Rate Taker
# 16189      Byron      Lewis        Lewis,  Byron  Water Rate Taker
# 24003  Francisco       Rios     Rios,  Francisco  Water Rate Taker
# 24501      Marco  Rodriguez  Rodriguez,  Marco A  Water Rate Taker
#
#              Department  Employee Annual Salary
# 0      Water Management                 90744.0
# 2400   Water Management                 78948.0
# 3143   Water Management                 82728.0
# 3456   Water Management                 90744.0
# 3626   Water Management                 90744.0
# 6954   Water Management                 90744.0
# 7641   Water Management                 90744.0
# 8092   Water Management                 78948.0
# 11857  Water Management                 78948.0
# 13729  Water Management                 75384.0
# 14771  Water Management                 90744.0
# 15215  Water Management                 86580.0
# 16189  Water Management                 90744.0
# 24003  Water Management                 78948.0
# 24501  Water Management                 90744.0
