# %%
1+1
# Out:
# 2

# %%
1+3
# Out:
# 4

# %%
#Code of 1+1
1+1
# Out:
# 2

# %%
bornDate=1998
thisYear=2019
Age=thisYear-bornDate
Age
# Out:
# 21

# %%
height=1.64
weight=58.5
bmi=weight/height**2
bmi
# Out:
# 21.75044616299822

# %%
"My name is Amin Hakim"
# Out:
# 'My name is Amin Hakim'

# %%
"My height us {}m and my weight is {}kg". format(height,weight)
# Out:
# 'My height us 1.64m and my weight is 58.5kg'

# %%
name="Muhamad Amin Hakim"
name[8:]
# Out:
# 'Amin Hakim'

# %%
type("I'm eating bread for breakfast")
# Out:
# str

# %%
type(12345)
# Out:
# int

# %%
False
# Out:
# False

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
money=35
money
# Out:
# 35

# %%
money=money+5
money
# Out:
# 40

# %%
firstName="Amin Hakim"
lastname="Sazali"
Full_Name=firstName+ " " + lastname
print(Full_Name)
# Out:
# Amin Hakim Sazali

# %%
{1,2,3,4}
# Out:
# {1, 2, 3, 4}

# %%
["John", "Ali","Abu"]
# Out:
# ['John', 'Ali', 'Abu']

# %%
type(["3.14,25.42,56.7"])
# Out:
# list

# %%
listA = ["John","Ali", 45,50,24.5,26.7]
print(listA)
# Out:
# ['John', 'Ali', 45, 50, 24.5, 26.7]

# %%
len(listA)
# Out:
# 6

# %%
name=["John","Ali","Abu","Aliff"]
print(name[0])
# Out:
# John

# %%
name[len(name)-1]
# Out:
# 'Aliff'

# %%
print(name[-1])
# Out:
# Aliff

# %%
print(name[2:4])
# Out:
# ['Abu', 'Aliff']

# %%
menu={
    "Filet-O-Fish":10,
    "Starbucks":12.50,
    "Fried Rice":5.99,
    "Fried Noodle": 5.99,
    "Big Mac":8.75
}

# %% [markdown]
# menu["Fried Rice"]

# %%
menu["Fried Rice"]
# Out:
# 5.99

# %%
menu["Tuna"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-58832d2dc292> in <module>()
# ----> 1 menu["Tuna"]
#
# KeyError: 'Tuna'

# %%
menu["Starbucks"]
# Out:
# 12.5

# %%
salary=4000

if salary > 3000:
    print ("High Salary")
else:
    print("Low Salary")
# Out:
# High Salary

# %%
salary = 3000

if salary > 3000:
    print ("High Salary")
else:
    print ("Low Salary")
# Out:
# Low Salary

# %%
item = ["orange","apple","mango","papaya","carrot","butterhead"]

if "orange" in item:
    print ("Yes! Orange in the list.")
# Out:
# Yes! Orange in the list.

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
for i in range(6):
    print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
items = ["orange","apple","mango","papaya","carrot","butterhead"]

for barang in items:
    print(barang)
# Out:
# orange
# apple
# mango
# papaya
# carrot
# butterhead

# %%
print(items[0])
print(items[1])
print(items[2])
print(items[3])
print(items[4])
print(items[5])
# Out:
# orange
# apple
# mango
# papaya
# carrot
# butterhead

# %%
student_ID={
    'Amin':'170028',
    'Aliff': '170030',
    'Luqman': '170026',
    'Aqiff':'170001',
}

for ID in student_ID.keys():
    print(ID)
# Out:
# Amin
# Aliff
# Luqman
# Aqiff

# %% [markdown]
# ic_or_email="aminhakimsazalu@gmail.com"

# %%
ic_or_email="aminhakimsazali@gmail.com"
# ic_or_email = "570121-87-2911"

if "@" in ic_or_email:
    print("Email:", ic_or_email)
else:
    print("IC No.:", ic_or_email)
# Out:
# Email: aminhakimsazali@gmail.com

# %% [markdown]
# items = ["papaya","carrot","butterhead"}

# %%
items = ["papaya", "carrot", "butterhead"]
         
if ("orange" or "apple") in items:
         print("Fruits in the list.")
elif "carrot" in items:
         print("Vegetable in the list.")
elif "butterhead" in items:
         print("Butterhead in the list.")
else:
        print("You dont buy any fruit or vegetables! Eat healthy!")
# Out:
# Vegetable in the list.

# %%
for i in range(5):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
for i in range(6):
    print ("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
items = ["orange","apple","mango","papaya","carrot","butterhead"]

for barang in items:
    print(barang)
# Out:
# orange
# apple
# mango
# papaya
# carrot
# butterhead

# %%
print(items[0])
print(items[1])
print(items[2])
print(items[3])
print(items[4])
print(items[5])
# Out:
# orange
# apple
# mango
# papaya
# carrot
# butterhead

# %%
student_ID={
    'Amin':'170028',
    'Aliff': '170030',
    'Luqman': '170026',
    'Aqiff':'170001',
}

for ID in student_ID.keys():
    print(ID)
# Out:
# Amin
# Aliff
# Luqman
# Aqiff

# %%
name='AMIRUL ASHRAFF'

for character in name:
    print (character)
# Out:
# A
# M
# I
# R
# U
# L
#
# A
# S
# H
# R
# A
# F
# F

# %%
i=0
while (i<5):
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
i=0
while (i<=6):
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(10):
    if i == 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(10):
    if i >= 3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(10):
    if i > 3:
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for i in range(10):
    if i == 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(10):
    if i > 3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
print("i\tj")
for i in range(5):
    for j in range(3):
        print("{}\t{}".format(i,j))
# Out:
# i	j
# 0	0
# 0	1
# 0	2
# 1	0
# 1	1
# 1	2
# 2	0
# 2	1
# 2	2
# 3	0
# 3	1
# 3	2
# 4	0
# 4	1
# 4	2

# %%
import pandas as pd

# %%
ice_cream=["Chocolate","Banana","Vanilla","Strawberry"]
pd.Series(ice_cream)
# Out:
# 0     Chocolate
# 1        Banana
# 2       Vanilla
# 3    Strawberry
# dtype: object

# %%
lottery=[34,74,12,98,19]
pd.Series(lottery)
# Out:
# 0    34
# 1    74
# 2    12
# 3    98
# 4    19
# dtype: int64

# %%
combine=ice_cream+lottery
pd.Series(combine)
# Out:
# 0     Chocolate
# 1        Banana
# 2       Vanilla
# 3    Strawberry
# 4            34
# 5            74
# 6            12
# 7            98
# 8            19
# dtype: object

# %%
combine=lottery+ice_cream
pd.Series(combine)
# Out:
# 0            34
# 1            74
# 2            12
# 3            98
# 4            19
# 5     Chocolate
# 6        Banana
# 7       Vanilla
# 8    Strawberry
# dtype: object

# %%
student_grade={
    "Amin":"80",
    "Senoi":"90",
    "Danial":"89",
    "Aqiff":"100"
}
pd.Series(student_grade)
# Out:
# Amin       80
# Senoi      90
# Danial     89
# Aqiff     100
# dtype: object

# %%
student_grade={
    "Amin":[88,79,99,87],
    "Senoi":[99,76,97,84],
    "Danial":[82,49,59,87],
    "Aqiff":[78,79,69,37]
}
pdStudent=pd.Series(student_grade)
pdStudent
# Out:
# Amin      [88, 79, 99, 87]
# Senoi     [99, 76, 97, 84]
# Danial    [82, 49, 59, 87]
# Aqiff     [78, 79, 69, 37]
# dtype: object

# %%
pdStudent["Amin"]
# Out:
# [88, 79, 99, 87]

# %%
lottery=[34,74,12,98,19]
s=pd.Series(lottery)
s
# Out:
# 0    34
# 1    74
# 2    12
# 3    98
# 4    19
# dtype: int64

# %%
s.values
# Out:
# array([34, 74, 12, 98, 19], dtype=int64)

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s.dtypes
# Out:
# dtype('int64')

# %%
s.sum
# Out:
# <bound method Series.sum of 0    34
# 1    74
# 2    12
# 3    98
# 4    19
# dtype: int64>

# %%
s.sum()
# Out:
# 237

# %%
s.count()
# Out:
# 5

# %%
s.count
# Out:
# <bound method Series.count of 0    34
# 1    74
# 2    12
# 3    98
# 4    19
# dtype: int64>

# %%
s.sum()/s.count()
# Out:
# 47.4

# %%
s.mean()
# Out:
# 47.4

# %%
s.product()
# Out:
# 56217504

# %%
pd.Series()
# Out:
# Series([], dtype: float64)

# %%
student_name=["Amin","Senoi","Danial","Aqiff",]
grade=[88,79,99,87]

pd.Series(grade,student_name)
# Out:
# Amin      88
# Senoi     79
# Danial    99
# Aqiff     87
# dtype: int64

# %%
pd.Series(data=grade,index=student_name)
# Out:
# Amin      88
# Senoi     79
# Danial    99
# Aqiff     87
# dtype: int64

# %%
pd.Series(data=student_name,index=grade)
# Out:
# 88      Amin
# 79     Senoi
# 99    Danial
# 87     Aqiff
# dtype: object

# %%
student_name=["Amin","Senoi","Danial","Aqiff","Amin"]
grade=[88,79,99,87,50]

s=pd.Series(grade,student_name)
s
# Out:
# Amin      88
# Senoi     79
# Danial    99
# Aqiff     87
# Amin      50
# dtype: int64

# %%
s["Amin"]
# Out:
# Amin    88
# Amin    50
# dtype: int64

# %% [markdown]
# pd.read_csv("data/pokemon.csv").head()

# %%
pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv").head()
# Out:
#       Pokemon   Type
# 0   Bulbasaur  Grass
# 1     Ivysaur  Grass
# 2    Venusaur  Grass
# 3  Charmander   Fire
# 4  Charmeleon   Fire

# %%
pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv", usecols=["Pokemon"]).head()
# Out:
#       Pokemon
# 0   Bulbasaur
# 1     Ivysaur
# 2    Venusaur
# 3  Charmander
# 4  Charmeleon

# %%
pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv", usecols=["Pokemon"],squeeze=True).head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
pokemon = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv", usecols=["Pokemon"], squeeze = True)
pokemon
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
# 5       Charizard
# 6        Squirtle
# 7       Wartortle
# 8       Blastoise
# 9        Caterpie
# 10        Metapod
# 11     Butterfree
# 12         Weedle
# 13         Kakuna
# 14       Beedrill
# 15         Pidgey
# 16      Pidgeotto
# 17        Pidgeot
# 18        Rattata
# 19       Raticate
# 20        Spearow
# 21         Fearow
# 22          Ekans
# 23          Arbok
# 24        Pikachu
# 25         Raichu
# 26      Sandshrew
# 27      Sandslash
# 28        Nidoran
# 29       Nidorina
#           ...
# 691     Clauncher
# 692     Clawitzer
# 693    Helioptile
# 694     Heliolisk
# 695        Tyrunt
# 696     Tyrantrum
# 697        Amaura
# 698       Aurorus
# 699       Sylveon
# 700      Hawlucha
# 701       Dedenne
# 702       Carbink
# 703         Goomy
# 704       Sliggoo
# 705        Goodra
# 706        Klefki
# 707      Phantump
# 708     Trevenant
# 709     Pumpkaboo
# ...

# %%
pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\google_stock_price.csv")
# Out:
#       Stock Price
# 0           50.12
# 1           54.10
# 2           54.65
# 3           52.38
# 4           52.95
# 5           53.90
# 6           53.02
# 7           50.95
# 8           51.13
# 9           50.07
# 10          50.70
# 11          49.95
# 12          50.74
# 13          51.10
# 14          51.10
# 15          52.61
# 16          53.70
# 17          55.69
# 18          55.94
# 19          56.93
# 20          58.69
# 21          59.62
# 22          58.86
# 23          59.13
# 24          60.35
# 25          59.86
# 26          59.07
# 27          63.37
# 28          65.47
# 29          64.74
# ...           ...
# 2982       675.22
# 2983       668.26
# 2984       680.04
# 2985       684.11
# 2986       692.10
# 2987       699.21
# 2988       694.49
# 2989       697.77
# 2990       695.36
# 2991       705.63
# 2992       715.09
# 2993       720.64
# 2994       716.98
# 2995       720.95
# 2996       719.85
# 2997       733.78
# 2998       736.96
# 2999       741.19
# ...

# %%
google=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\google_stock_price.csv", squeeze = True)
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
# 5        53.90
# 6        53.02
# 7        50.95
# 8        51.13
# 9        50.07
# 10       50.70
# 11       49.95
# 12       50.74
# 13       51.10
# 14       51.10
# 15       52.61
# 16       53.70
# 17       55.69
# 18       55.94
# 19       56.93
# 20       58.69
# 21       59.62
# 22       58.86
# 23       59.13
# 24       60.35
# 25       59.86
# 26       59.07
# 27       63.37
# 28       65.47
# 29       64.74
#          ...
# 2982    675.22
# 2983    668.26
# 2984    680.04
# 2985    684.11
# 2986    692.10
# 2987    699.21
# 2988    694.49
# 2989    697.77
# 2990    695.36
# 2991    705.63
# 2992    715.09
# 2993    720.64
# 2994    716.98
# 2995    720.95
# 2996    719.85
# 2997    733.78
# 2998    736.96
# 2999    741.19
# 3000    738.63
# 3001    742.74
# 3002    739.77
# 3003    738.42
# 3004    741.77
# 3005    745.91
# 3006    768.79
# 3007    772.88
# 3008    771.07
# ...

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
pokemon.tail()
# Out:
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pokemon, dtype: object

# %%
pokemon.head(10)
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# 5     Charizard
# 6      Squirtle
# 7     Wartortle
# 8     Blastoise
# 9      Caterpie
# Name: Pokemon, dtype: object

# %%
len(pokemon), len(google)
# Out:
# (721, 3012)

# %%
type(pokemon)
# Out:
# pandas.core.series.Series

# %%
dir(pokemon)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
# ...

# %%
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Bronzong',
#  'Bronzor',
#  'Budew',
#  'Buizel',
#  'Bulbasaur',
#  'Buneary',
#  'Bunnelby',
# ...

# %%
sorted(google)
# Out:
# [49.95,
#  50.07,
#  50.12,
#  50.7,
#  50.74,
#  50.95,
#  51.1,
#  51.1,
#  51.13,
#  52.38,
#  52.61,
#  52.95,
#  53.02,
#  53.7,
#  53.9,
#  54.1,
#  54.65,
#  55.69,
#  55.94,
#  56.93,
#  58.69,
#  58.86,
#  59.07,
#  59.13,
#  59.62,
#  59.86,
#  60.35,
#  63.37,
#  64.74,
#  65.47,
#  66.22,
#  67.46,
#  67.56,
#  68.47,
#  68.63,
#  68.8,
#  69.12,
#  69.36,
#  70.17,
#  70.38,
#  70.93,
#  71.98,
#  73.9,
#  74.51,
#  74.62,
#  82.47,
#  83.68,
#  83.69,
#  83.85,
#  84.27,
#  84.59,
#  84.62,
#  84.91,
#  85.14,
#  85.63,
#  85.74,
#  86.13,
#  86.16,
#  86.19,
#  86.19,
#  86.63,
#  87.29,
#  87.41,
#  87.71,
#  88.06,
#  88.15,
#  88.47,
#  88.81,
#  89.21,
#  89.22,
#  89.26,
#  89.4,
#  89.54,
#  89.56,
#  89.61,
#  89.61,
#  89.7,
#  89.8,
#  89.89,
#  89.9,
#  89.93,
#  89.93,
#  89.95,
#  90.11,
#  90.13,
#  90.16,
#  90.27,
#  90.35,
#  90.43,
#  90.58,
#  90.62,
#  90.81,
#  90.9,
#  90.91,
#  91.42,
#  91.78,
#  92.26,
#  92.34,
#  92.41,
#  92.42,
#  92.5,
# ...

# %%
dict(google)
# Out:
# {0: 50.12,
#  1: 54.1,
#  2: 54.65,
#  3: 52.38,
#  4: 52.95,
#  5: 53.9,
#  6: 53.02,
#  7: 50.95,
#  8: 51.13,
#  9: 50.07,
#  10: 50.7,
#  11: 49.95,
#  12: 50.74,
#  13: 51.1,
#  14: 51.1,
#  15: 52.61,
#  16: 53.7,
#  17: 55.69,
#  18: 55.94,
#  19: 56.93,
#  20: 58.69,
#  21: 59.62,
#  22: 58.86,
#  23: 59.13,
#  24: 60.35,
#  25: 59.86,
#  26: 59.07,
#  27: 63.37,
#  28: 65.47,
#  29: 64.74,
#  30: 66.22,
#  31: 67.46,
#  32: 69.12,
#  33: 68.47,
#  34: 69.36,
#  35: 68.8,
#  36: 67.56,
#  37: 68.63,
#  38: 70.38,
#  39: 70.93,
#  40: 71.98,
#  41: 74.51,
#  42: 73.9,
#  43: 70.17,
#  44: 74.62,
#  45: 86.13,
#  46: 93.61,
#  47: 90.81,
#  48: 92.89,
#  49: 96.55,
#  50: 95.22,
#  51: 97.92,
#  52: 97.34,
#  53: 95.74,
#  54: 92.26,
#  55: 84.59,
#  56: 86.19,
#  57: 84.27,
#  58: 83.85,
#  59: 91.42,
#  60: 90.91,
#  61: 92.34,
#  62: 86.19,
#  63: 86.16,
#  64: 83.69,
#  65: 84.62,
#  66: 82.47,
#  67: 83.68,
#  68: 87.29,
#  69: 89.61,
#  70: 90.43,
#  71: 90.9,
# ...

# %%
max(google)
# Out:
# 782.22

# %%
min(pokemon)
# Out:
# 'Abomasnow'

# %%
pokemon.is_unique
# Out:
# True

# %%
google.is_unique
# Out:
# False

# %%
google.ndim
# Out:
# 1

# %%
google.shape
# Out:
# (3012,)

# %%
google.size
# Out:
# 3012

# %%
pokemon.ndim
# Out:
# 1

# %%
pokemon.shape
# Out:
# (721,)

# %%
pokemon.size
# Out:
# 721

# %%
pokemon.name = "Pocket Monsters"

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pocket Monsters, dtype: object

# %%
pokemon.sort_values().head()
# Out:
# 459    Abomasnow
# 62          Abra
# 358        Absol
# 616     Accelgor
# 680    Aegislash
# Name: Pocket Monsters, dtype: object

# %%
pokemon.sort_values(ascending=False).head
# Out:
# <bound method NDFrame.head of 717       Zygarde
# 633      Zweilous
# 40          Zubat
# 569         Zorua
# 570       Zoroark
# 262     Zigzagoon
# 643        Zekrom
# 522     Zebstrika
# 144        Zapdos
# 334      Zangoose
# 716       Yveltal
# 468       Yanmega
# 192         Yanma
# 561        Yamask
# 715       Xerneas
# 177          Xatu
# 359        Wynaut
# 264       Wurmple
# 412      Wormadam
# 193        Wooper
# 526        Woobat
# 201     Wobbuffet
# 277       Wingull
# 39     Wigglytuff
# 292       Whismur
# 339      Whiscash
# 543    Whirlipede
# 546    Whimsicott
# 109       Weezing
# 69     Weepinbell
#           ...
# 609          Axew
# 712       Avalugg
# 698       Aurorus
# 530        Audino
# 143      Articuno
# 303          Aron
# 682    Aromatisse
# 347       Armaldo
# 167       Ariados
# 566      Archeops
# 565        Archen
# 492        Arceus
# 58       Arcanine
# 23          Arbok
# 346       Anorith
# 180      Ampharos
# 590     Amoonguss
# ...

# %%
google.max()
# Out:
# 782.22

# %%
google.sort_values(ascending=False).head(1)
# Out:
# 3011    782.22
# Name: Stock Price, dtype: float64

# %%
google.head(3)
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# Name: Stock Price, dtype: float64

# %%
google.sort_values(ascending=False, inplace = True)

# %%
google.head(3)
# Out:
# 3011    782.22
# 2859    776.60
# 3009    773.18
# Name: Stock Price, dtype: float64

# %%
google.sort_values(ascending=False, inplace=True)

# %%
google.head(3)
# Out:
# 3011    782.22
# 2859    776.60
# 3009    773.18
# Name: Stock Price, dtype: float64

# %%
pokemon.sort_values(ascending=False, inplace=True)
pokemon.head()
# Out:
# 717     Zygarde
# 633    Zweilous
# 40        Zubat
# 569       Zorua
# 570     Zoroark
# Name: Pocket Monsters, dtype: object

# %%
pokemon.sort_index(inplace = True)
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pocket Monsters, dtype: object

# %%
3 in [1,2,3,4,5]
# Out:
# True

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pocket Monsters, dtype: object

# %%
"Bulbasaur" in pokemon
# Out:
# False

# %%
"Bulbasaur" in pokemon.values
# Out:
# True

# %%
pokemon.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pocket Monsters, dtype: object

# %%
pokemon[0]
# Out:
# 'Bulbasaur'

# %%
pokemon.tail()
# Out:
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pocket Monsters, dtype: object

# %%
pokemon[720]
# Out:
# 'Volcanion'

# %%
lst=[100,200,300,400]

pokemon[lst]
# Out:
# 100    Electrode
# 200        Unown
# 300     Delcatty
# 400    Kricketot
# Name: Pocket Monsters, dtype: object

# %%
pokemon[10:21]
# Out:
# 10       Metapod
# 11    Butterfree
# 12        Weedle
# 13        Kakuna
# 14      Beedrill
# 15        Pidgey
# 16     Pidgeotto
# 17       Pidgeot
# 18       Rattata
# 19      Raticate
# 20       Spearow
# Name: Pocket Monsters, dtype: object

# %%
pokemon[-10:]
# Out:
# 711     Bergmite
# 712      Avalugg
# 713       Noibat
# 714      Noivern
# 715      Xerneas
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pocket Monsters, dtype: object

# %%
pokemon=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv", index_col="Pokemon", squeeze = True)
pokemon.head()
# Out:
# Pokemon
# Bulbasaur     Grass
# Ivysaur       Grass
# Venusaur      Grass
# Charmander     Fire
# Charmeleon     Fire
# Name: Type, dtype: object

# %%
pokemon=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv", index_col="Pokemon", squeeze = True)
pokemon.head(3)
# Out:
# Pokemon
# Bulbasaur    Grass
# Ivysaur      Grass
# Venusaur     Grass
# Name: Type, dtype: object

# %%
pokemon=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv", index_col="Pokemon", squeeze = False)
pokemon.head(3)
# Out:
#             Type
# Pokemon
# Bulbasaur  Grass
# Ivysaur    Grass
# Venusaur   Grass

# %%
pokemon=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv", index_col="Pokemon", squeeze = False)
pokemon.head()
# Out:
#              Type
# Pokemon
# Bulbasaur   Grass
# Ivysaur     Grass
# Venusaur    Grass
# Charmander   Fire
# Charmeleon   Fire

# %%
pokemon["Bulbasaur","Ditto","Meowth"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-acddce1a2925> in <module>
# ----> 1 pokemon["Bulbasaur","Ditto","Meowth"]
#
# NameError: name 'pokemon' is not defined

# %%
pokemon=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\pokemon.csv", index_col="Pokemon", squeeze = True)
pokemon.head(3)
# Out:
# Pokemon
# Bulbasaur    Grass
# Ivysaur      Grass
# Venusaur     Grass
# Name: Type, dtype: object

# %%
pokemon[["Bulbasaur","Ditto","Meowth"]]
# Out:
# Pokemon
# Bulbasaur     Grass
# Ditto        Normal
# Meowth       Normal
# Name: Type, dtype: object

# %%
pokemon["Digimon"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3108             try:
# -> 3109                 return libindex.get_value_box(s, key)
#    3110             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-204-ca2af26142e2> in <module>()
# ----> 1 pokemon["Digimon"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# ...

# %%
pokemon[["Meowth","Digimon","Charizard"]]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:850: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# Pokemon
# Meowth       Normal
# Digimon         NaN
# Charizard      Fire
# Name: Type, dtype: object

# %%
pokemon["Metapod":"Spearow"]
# Out:
# Pokemon
# Metapod          Bug
# Butterfree       Bug
# Weedle           Bug
# Kakuna           Bug
# Beedrill         Bug
# Pidgey        Normal
# Pidgeotto     Normal
# Pidgeot       Normal
# Rattata       Normal
# Raticate      Normal
# Spearow       Normal
# Name: Type, dtype: object

# %%
pokemon.head(3)
# Out:
# Pokemon
# Bulbasaur    Grass
# Ivysaur      Grass
# Venusaur     Grass
# Name: Type, dtype: object

# %%
pokemon.get("Bulbasaur")
# Out:
# 'Grass'

# %%
pokemon.get("Digimon")

# %%
pokemon.get(["Bulbasaur","Meowth"])
# Out:
# Pokemon
# Bulbasaur     Grass
# Meowth       Normal
# Name: Type, dtype: object

# %%
pokemon.get(["Bulbasaur","Meowth","Digimon"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:850: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# Pokemon
# Bulbasaur     Grass
# Meowth       Normal
# Digimon         NaN
# Name: Type, dtype: object

# %%
pet = "Charizard"
if pokemon.get(pet):
    print("Charizard")
else:
    print ("Not Available")
# Out:
# Charizard

# %%
google = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\google_stock_price.csv",squeeze = True) 
google.head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64

# %%
google.median ()
# Out:
# 283.315

# %%
google.describe()
# Out:
# count    3012.000000
# mean      334.310093
# std       173.187205
# min        49.950000
# 25%       218.045000
# 50%       283.315000
# 75%       443.000000
# max       782.220000
# Name: Stock Price, dtype: float64

# %%
IQR = google.describe()["75%"]-google.describe()["25%"]
IQR
# Out:
# 224.95499999999998

# %%
lowerFence = google.describe()["25%"]-1.5*IQR
lowerFence
# Out:
# -119.38749999999999

# %%
upperFence = google.describe()["75%"]+1.5*IQR
upperFence
# Out:
# 780.4325

# %%
import pandas as pd

# %%
nba = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba
# Out:
#                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.head
# Out:
# <bound method NDFrame.head of                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.tail
# Out:
# <bound method NDFrame.tail of                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 4              Jonas Jerebko          Boston Celtics     8.0       PF  29.0
# 5               Amir Johnson          Boston Celtics    90.0       PF  29.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# ...

# %%
nba.tail(3)
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.get_dtype_counts()
# Out:
# float64    4
# object     5
# dtype: int64

# %%
rev = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\revenue.csv",index_col="Date")
rev.head()
# Out:
#         New York  Los Angeles  Miami
# Date
# 1/1/16       985          122    499
# 1/2/16       738          788    534
# 1/3/16        14           20    933
# 1/4/16       730          904    885
# 1/5/16       114           71    253

# %%
rev.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
rev.sum(axis="columns")
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
rev["Sum by day"]=rev.sum(axis=1)

# %%
rev.head()
# Out:
#         New York  Los Angeles  Miami  Sum by day
# Date
# 1/1/16       985          122    499        1606
# 1/2/16       738          788    534        2060
# 1/3/16        14           20    933         967
# 1/4/16       730          904    885        2519
# 1/5/16       114           71    253         438

# %%
nba = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba[["Name","Salary"]].head()
# Out:
#             Name     Salary
# 0  Avery Bradley  7730337.0
# 1    Jae Crowder  6796117.0
# 2   John Holland        NaN
# 3    R.J. Hunter  1148640.0
# 4  Jonas Jerebko  5000000.0

# %%
nba[["Name","Salary","College"]].head()
# Out:
#             Name     Salary            College
# 0  Avery Bradley  7730337.0              Texas
# 1    Jae Crowder  6796117.0          Marquette
# 2   John Holland        NaN  Boston University
# 3    R.J. Hunter  1148640.0      Georgia State
# 4  Jonas Jerebko  5000000.0                NaN

# %%
nba = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Sport"]="Basketball"

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
nba = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")

# %%
nba.insert(loc=3,column="Sport",value="Basketball")

# %%
nba.head(3)
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN

# %%
nba["Age"].add(5).head()
# Out:
# 0    30.0
# 1    30.0
# 2    32.0
# 3    27.0
# 4    34.0
# Name: Age, dtype: float64

# %%
nba["Salary"].sub(100000).head(10)
# Out:
# 0     7630337.0
# 1     6696117.0
# 2           NaN
# 3     1048640.0
# 4     4900000.0
# 5    11900000.0
# 6     1070960.0
# 7     2065160.0
# 8     1724360.0
# 9     3331040.0
# Name: Salary, dtype: float64

# %%
nba["Weight in Kilogram"]=nba["Weight"].mul(0.453592)

# %%
nba.head()
# Out:
#             Name            Team  Number       Sport Position   Age Height  \
# 0  Avery Bradley  Boston Celtics     0.0  Basketball       PG  25.0    6-2
# 1    Jae Crowder  Boston Celtics    99.0  Basketball       SF  25.0    6-6
# 2   John Holland  Boston Celtics    30.0  Basketball       SG  27.0    6-5
# 3    R.J. Hunter  Boston Celtics    28.0  Basketball       SG  22.0    6-5
# 4  Jonas Jerebko  Boston Celtics     8.0  Basketball       PF  29.0   6-10
#
#    Weight            College     Salary  Weight in Kilogram
# 0   180.0              Texas  7730337.0           81.646560
# 1   235.0          Marquette  6796117.0          106.594120
# 2   205.0  Boston University        NaN           92.986360
# 3   185.0      Georgia State  1148640.0           83.914520
# 4   231.0                NaN  5000000.0          104.779752

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba["Position"].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba["Team"].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Milwaukee Bucks           16
# New York Knicks           16
# Portland Trail Blazers    15
# Philadelphia 76ers        15
# Brooklyn Nets             15
# Phoenix Suns              15
# Golden State Warriors     15
# Denver Nuggets            15
# Indiana Pacers            15
# Chicago Bulls             15
# Atlanta Hawks             15
# Oklahoma City Thunder     15
# Utah Jazz                 15
# Charlotte Hornets         15
# Los Angeles Lakers        15
# Houston Rockets           15
# Cleveland Cavaliers       15
# Los Angeles Clippers      15
# Boston Celtics            15
# Washington Wizards        15
# San Antonio Spurs         15
# Miami Heat                15
# Sacramento Kings          15
# Toronto Raptors           15
# Detroit Pistons           15
# Dallas Mavericks          15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0  Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0     NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0     NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457           NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457        NaN

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
# Name        457 non-null object
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.dropna(how="all",inplace=True)

# %%
nba.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
nba.dropna(inplace=True)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
# Name        364 non-null object
# Team        364 non-null object
# Number      364 non-null float64
# Position    364 non-null object
# Age         364 non-null float64
# Height      364 non-null object
# Weight      364 non-null float64
# College     364 non-null object
# Salary      364 non-null float64
# dtypes: float64(4), object(5)
# memory usage: 28.4+ KB

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.dropna(how="all",inplace=True)
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.dropna(axis=1).head()
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.dropna(how="all",inplace=True)
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.dropna(subset=["College"],inplace = True)
nba.head
# Out:
# <bound method NDFrame.head of                         Name                    Team  Number Position   Age  \
# 0              Avery Bradley          Boston Celtics     0.0       PG  25.0
# 1                Jae Crowder          Boston Celtics    99.0       SF  25.0
# 2               John Holland          Boston Celtics    30.0       SG  27.0
# 3                R.J. Hunter          Boston Celtics    28.0       SG  22.0
# 6              Jordan Mickey          Boston Celtics    55.0       PF  21.0
# 7               Kelly Olynyk          Boston Celtics    41.0        C  25.0
# 8               Terry Rozier          Boston Celtics    12.0       PG  22.0
# 9               Marcus Smart          Boston Celtics    36.0       PG  22.0
# 10           Jared Sullinger          Boston Celtics     7.0        C  24.0
# 11             Isaiah Thomas          Boston Celtics     4.0       PG  27.0
# 12               Evan Turner          Boston Celtics    11.0       SG  27.0
# ...

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.dropna(how="all",inplace=True)
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.dropna(subset=["College"], inplace = True)
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 6                LSU  1170960.0

# %%
nba.reset_index()
# Out:
#      index                     Name                    Team  Number Position  \
# 0        0            Avery Bradley          Boston Celtics     0.0       PG
# 1        1              Jae Crowder          Boston Celtics    99.0       SF
# 2        2             John Holland          Boston Celtics    30.0       SG
# 3        3              R.J. Hunter          Boston Celtics    28.0       SG
# 4        6            Jordan Mickey          Boston Celtics    55.0       PF
# 5        7             Kelly Olynyk          Boston Celtics    41.0        C
# 6        8             Terry Rozier          Boston Celtics    12.0       PG
# 7        9             Marcus Smart          Boston Celtics    36.0       PG
# 8       10          Jared Sullinger          Boston Celtics     7.0        C
# 9       11            Isaiah Thomas          Boston Celtics     4.0       PG
# 10      12              Evan Turner          Boston Celtics    11.0       SG
# ...

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.dropna(how="all", inplace=True)
mask=nba["Salary"].isna()
nba[mask].head()
# Out:
#               Name                 Team  Number Position   Age Height  Weight  \
# 2     John Holland       Boston Celtics    30.0       SG  27.0    6-5   205.0
# 46     Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9   254.0
# 171  Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6   225.0
# 264  Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2   180.0
# 269   Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3   190.0
#
#                College  Salary
# 2    Boston University     NaN
# 46                Duke     NaN
# 171               Duke     NaN
# 264               UCLA     NaN
# 269            Detroit     NaN

# %%
mean_Salary=nba["Salary"].mean()
mean_Salary
# Out:
# 4842684.105381166

# %%
nba["Salary"].fillna(mean_Salary, inplace=True)

# %%
nba["College"].fillna("No College", inplace=True)

# %%
nba[mask].head()
# Out:
#               Name                 Team  Number Position   Age Height  Weight  \
# 2     John Holland       Boston Celtics    30.0       SG  27.0    6-5   205.0
# 46     Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9   254.0
# 171  Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6   225.0
# 264  Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2   180.0
# 269   Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3   190.0
#
#                College        Salary
# 2    Boston University  4.842684e+06
# 46                Duke  4.842684e+06
# 171               Duke  4.842684e+06
# 264               UCLA  4.842684e+06
# 269            Detroit  4.842684e+06

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.dropna(inplace=True)
nba.reset_index(inplace=True)

# %%
nba.head()
# Out:
#    index           Name            Team  Number Position   Age Height  Weight  \
# 0      0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2      3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 3      6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 4      7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
#
#          College     Salary
# 0          Texas  7730337.0
# 1      Marquette  6796117.0
# 2  Georgia State  1148640.0
# 3            LSU  1170960.0
# 4        Gonzaga  2165160.0

# %%
nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 10 columns):
# index       364 non-null int64
# Name        364 non-null object
# Team        364 non-null object
# Number      364 non-null float64
# Position    364 non-null object
# Age         364 non-null float64
# Height      364 non-null object
# Weight      364 non-null float64
# College     364 non-null object
# Salary      364 non-null float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 28.5+ KB

# %%
nba["Number"]=nba["Number"].astype("int")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 10 columns):
# index       364 non-null int64
# Name        364 non-null object
# Team        364 non-null object
# Number      364 non-null int32
# Position    364 non-null object
# Age         364 non-null float64
# Height      364 non-null object
# Weight      364 non-null float64
# College     364 non-null object
# Salary      364 non-null float64
# dtypes: float64(3), int32(1), int64(1), object(5)
# memory usage: 27.1+ KB

# %%
nba["Team"]=nba["Team"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 10 columns):
# index       364 non-null int64
# Name        364 non-null object
# Team        364 non-null category
# Number      364 non-null int32
# Position    364 non-null object
# Age         364 non-null float64
# Height      364 non-null object
# Weight      364 non-null float64
# College     364 non-null object
# Salary      364 non-null float64
# dtypes: category(1), float64(3), int32(1), int64(1), object(4)
# memory usage: 26.1+ KB

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.sort_values(by="Name").head()
# Out:
#                Name                    Team  Number Position   Age Height  \
# 152    Aaron Brooks           Chicago Bulls     0.0       PG  31.0    6-0
# 356    Aaron Gordon           Orlando Magic     0.0       PF  20.0    6-9
# 328  Aaron Harrison       Charlotte Hornets     9.0       SG  21.0    6-6
# 404   Adreian Payne  Minnesota Timberwolves    33.0       PF  25.0   6-10
# 312      Al Horford           Atlanta Hawks    15.0        C  30.0   6-10
#
#      Weight         College      Salary
# 152   161.0          Oregon   2250000.0
# 356   220.0         Arizona   4171680.0
# 328   210.0        Kentucky    525093.0
# 404   237.0  Michigan State   1938840.0
# 312   245.0         Florida  12000000.0

# %%
nba.sort_values(by="Salary",ascending=False).head()
# Out:
#                 Name                 Team  Number Position   Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James  Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony      New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard      Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh           Miami Heat     1.0       PF  32.0   6-11
#
#      Weight       College      Salary
# 109   212.0           NaN  25000000.0
# 169   250.0           NaN  22970500.0
# 33    240.0      Syracuse  22875000.0
# 251   265.0           NaN  22359364.0
# 339   235.0  Georgia Tech  22192730.0

# %%
nba.sort_values(by="Salary",ascending=True).head()
# Out:
#                        Name                  Team  Number Position   Age  \
# 32   Thanasis Antetokounmpo       New York Knicks    43.0       SF  23.0
# 291         Orlando Johnson  New Orleans Pelicans     0.0       SG  27.0
# 130            Phil Pressey          Phoenix Suns    25.0       PG  25.0
# 135           Alan Williams          Phoenix Suns    15.0        C  23.0
# 175            Jordan McRae   Cleveland Cavaliers    12.0       SG  25.0
#
#     Height  Weight           College    Salary
# 32     6-7   205.0               NaN   30888.0
# 291    6-5   220.0  UC Santa Barbara   55722.0
# 130   5-11   175.0          Missouri   55722.0
# 135    6-8   260.0  UC Santa Barbara   83397.0
# 175    6-5   179.0         Tennessee  111196.0

# %%
nba.sort_values(by=["Team","Salary"],ascending=[True,False])
# Out:
#                  Name                Team  Number Position   Age Height  \
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    6-8
# 312        Al Horford       Atlanta Hawks    15.0        C  30.0   6-10
# 321    Tiago Splitter       Atlanta Hawks    11.0        C  31.0   6-11
# 323       Jeff Teague       Atlanta Hawks     0.0       PG  27.0    6-2
# 314       Kyle Korver       Atlanta Hawks    26.0       SG  35.0    6-7
# 320   Thabo Sefolosha       Atlanta Hawks    25.0       SF  32.0    6-7
# 319        Mike Scott       Atlanta Hawks    32.0       PF  27.0    6-8
# 311      Kirk Hinrich       Atlanta Hawks    12.0       SG  35.0    6-4
# 309     Kent Bazemore       Atlanta Hawks    24.0       SF  26.0    6-5
# 318   Dennis Schroder       Atlanta Hawks    17.0       PG  22.0    6-1
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    6-6
# 313    Kris Humphries       Atlanta Hawks    43.0       PF  31.0    6-9
# ...

# %%
nba=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\nba.csv")
nba.sort_values(by=["Team","Salary"],ascending=[True,False], inplace=True)
nba.head(3)
# Out:
#                Name           Team  Number Position   Age Height  Weight  \
# 315    Paul Millsap  Atlanta Hawks     4.0       PF  31.0    6-8   246.0
# 312      Al Horford  Atlanta Hawks    15.0        C  30.0   6-10   245.0
# 321  Tiago Splitter  Atlanta Hawks    11.0        C  31.0   6-11   245.0
#
#             College      Salary
# 315  Louisiana Tech  18671659.0
# 312         Florida  12000000.0
# 321             NaN   9756250.0

# %%
nba.sort_index().head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
import pandas as pd
bigmac = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\bigmac.csv", parse_dates = ["Date"])
bigmac.head()
# Out:
#         Date    Country  Price in US Dollars
# 0 2016-01-01  Argentina                 2.39
# 1 2016-01-01  Australia                 3.74
# 2 2016-01-01     Brazil                 3.35
# 3 2016-01-01    Britain                 4.22
# 4 2016-01-01     Canada                 4.14

# %%
bigmac["Date"].nunique()
# Out:
# 12

# %%
bigmac["Country"].nunique()
# Out:
# 58

# %%
bigmac.set_index(["Date","Country"], inplace = True)
bigmac
# Out:
#                            Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                      2.39
#            Australia                      3.74
#            Brazil                         3.35
#            Britain                        4.22
#            Canada                         4.14
#            Chile                          2.94
#            China                          2.68
#            Colombia                       2.43
#            Costa Rica                     4.02
#            Czech Republic                 2.98
#            Denmark                        4.32
#            Egypt                          2.16
#            Euro area                      4.00
#            Hong Kong                      2.48
#            Hungary                        3.08
#            India                          1.90
#            Indonesia                      2.19
#            Israel                         4.29
# ...

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35
#            Britain                   4.22
#            Canada                    4.14

# %%
bigmac = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\bigmac.csv", index_col=["Date","Country"],parse_dates = ["Date"])
bigmac.sort_index(inplace=True)
bigmac.head(10)
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71

# %%
bigmac = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\bigmac.csv", index_col=["Country","Date"],parse_dates = ["Date"])
bigmac.sort_index(inplace=True)
bigmac.head(10)
# Out:
#                       Price in US Dollars
# Country   Date
# Argentina 2010-01-01                 1.84
#           2010-07-01                 3.56
#           2011-07-01                 4.84
#           2012-01-01                 4.64
#           2012-07-01                 4.16
#           2013-01-01                 3.82
#           2013-07-01                 3.88
#           2014-01-01                 3.03
#           2014-07-01                 2.57
#           2015-01-01                 3.25

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index.names
# Out:
# FrozenList(['Country', 'Date'])

# %%
bigmac = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\bigmac.csv", index_col=["Date","Country"],parse_dates = ["Date"])
bigmac.sort_index(inplace=True)
bigmac.head(10)
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71

# %%
bigmac.index[0]
# Out:
# (Timestamp('2010-01-01 00:00:00'), 'Argentina')

# %%
bigmac.loc["2016-01-01","Italy"]
# Out:
# Price in US Dollars    4.3
# Name: (2016-01-01 00:00:00, Italy), dtype: float64

# %%
bigmac.index.get_level_values(level=0)
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values(level=1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %%
bigmac.index.set_names(["Day","Location"],inplace=True)
bigmac.head()
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.index.set_names(["Date","Country"], inplace = True)
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.sort_index(ascending = [True,False])
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                        3.32
#            United States                  3.58
#            Ukraine                        1.83
#            UAE                            2.99
#            Turkey                         3.83
#            Thailand                       2.11
#            Taiwan                         2.36
#            Switzerland                    6.30
#            Sweden                         5.51
#            Sri Lanka                      1.83
#            South Korea                    2.98
#            South Africa                   2.46
#            Singapore                      3.19
#            Saudi Arabia                   2.67
#            Russia                         2.34
#            Poland                         2.86
#            Philippines                    2.21
#            Peru                           2.81
# ...

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.loc[("2010-01-01","Argentina"),"Price in US Dollars"]
# Out:
# Date        Country
# 2010-01-01  Argentina    1.84
# Name: Price in US Dollars, dtype: float64

# %%
type(("2010-01-01","Argentina"))
# Out:
# tuple

# %%
type("2010-01-01","Argentina")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-63bd4297b2de> in <module>()
# ----> 1 type("2010-01-01","Argentina")
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(("2010-01-01","Argentina"))
# Out:
# tuple

# %%
bigmac.loc[("2010-01-01"),"Price in US Dollars"]
# Out:
# Date        Country
# 2010-01-01  Argentina         1.84
#             Australia         3.98
#             Brazil            4.76
#             Britain           3.67
#             Canada            3.97
#             Chile             3.18
#             China             1.83
#             Colombia          3.91
#             Costa Rica        3.52
#             Czech Republic    3.71
#             Denmark           5.99
#             Egypt             2.38
#             Euro area         4.84
#             Hong Kong         1.91
#             Hungary           3.86
#             Indonesia         2.24
#             Israel            3.99
#             Japan             3.50
#             Latvia            3.09
#             Lithuania         2.87
#             Malaysia          2.08
#             Mexico            2.50
#             New Zealand       3.61
#             Norway            7.02
#             Pakistan          2.42
#             Peru              2.81
# ...

# %%
bigmac
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
bigmac.transpose()
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                     ...    2016-01-01  \
# Country             Colombia Costa Rica Czech Republic   ...   Switzerland
# Price in US Dollars     3.91       3.52           3.71   ...          6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
#Creating the DataFrame
df = pd.DataFrame({"A":[12 , 4 , 5 , None , 1],
                   "B":[7 , 2 , 54 , 3 , None],
                   "C": [20, 16, 11 , 3, 8],
                   "D": [14, 3 , None , 2 , 6]})
df
# Out:
#       A     B   C     D
# 0  12.0   7.0  20  14.0
# 1   4.0   2.0  16   3.0
# 2   5.0  54.0  11   NaN
# 3   NaN   3.0   3   2.0
# 4   1.0   NaN   8   6.0

# %%
df.transpose()
# Out:
#       0     1     2    3    4
# A  12.0   4.0   5.0  NaN  1.0
# B   7.0   2.0  54.0  3.0  NaN
# C  20.0  16.0  11.0  3.0  8.0
# D  14.0   3.0   NaN  2.0  6.0

# %%
bigmac.head()
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76
#            Britain                   3.67
#            Canada                    3.97

# %%
bigmac.swaplevel(i="Date",j="Country")
# Out:
#                            Price in US Dollars
# Country        Date
# Argentina      2010-01-01                 1.84
# Australia      2010-01-01                 3.98
# Brazil         2010-01-01                 4.76
# Britain        2010-01-01                 3.67
# Canada         2010-01-01                 3.97
# Chile          2010-01-01                 3.18
# China          2010-01-01                 1.83
# Colombia       2010-01-01                 3.91
# Costa Rica     2010-01-01                 3.52
# Czech Republic 2010-01-01                 3.71
# Denmark        2010-01-01                 5.99
# Egypt          2010-01-01                 2.38
# Euro area      2010-01-01                 4.84
# Hong Kong      2010-01-01                 1.91
# Hungary        2010-01-01                 3.86
# Indonesia      2010-01-01                 2.24
# Israel         2010-01-01                 3.99
# Japan          2010-01-01                 3.50
# ...

# %%
bigmac.stack()
# Out:
# Date        Country
# 2010-01-01  Argentina       Price in US Dollars    1.84
#             Australia       Price in US Dollars    3.98
#             Brazil          Price in US Dollars    4.76
#             Britain         Price in US Dollars    3.67
#             Canada          Price in US Dollars    3.97
#             Chile           Price in US Dollars    3.18
#             China           Price in US Dollars    1.83
#             Colombia        Price in US Dollars    3.91
#             Costa Rica      Price in US Dollars    3.52
#             Czech Republic  Price in US Dollars    3.71
#             Denmark         Price in US Dollars    5.99
#             Egypt           Price in US Dollars    2.38
#             Euro area       Price in US Dollars    4.84
#             Hong Kong       Price in US Dollars    1.91
#             Hungary         Price in US Dollars    3.86
#             Indonesia       Price in US Dollars    2.24
# ...

# %%
bigmac.stack().to_frame()
# Out:
#                                                   0
# Date       Country
# 2010-01-01 Argentina      Price in US Dollars  1.84
#            Australia      Price in US Dollars  3.98
#            Brazil         Price in US Dollars  4.76
#            Britain        Price in US Dollars  3.67
#            Canada         Price in US Dollars  3.97
#            Chile          Price in US Dollars  3.18
#            China          Price in US Dollars  1.83
#            Colombia       Price in US Dollars  3.91
#            Costa Rica     Price in US Dollars  3.52
#            Czech Republic Price in US Dollars  3.71
#            Denmark        Price in US Dollars  5.99
#            Egypt          Price in US Dollars  2.38
#            Euro area      Price in US Dollars  4.84
#            Hong Kong      Price in US Dollars  1.91
#            Hungary        Price in US Dollars  3.86
#            Indonesia      Price in US Dollars  2.24
#            Israel         Price in US Dollars  3.99
# ...

# %%
world=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\worldstats.csv",index_col=["country","year"])
world.head()
# Out:
#                   Population           GDP
# country    year
# Arab World 2015  392022276.0  2.530102e+12
#            2014  384222592.0  2.873600e+12
#            2013  376504253.0  2.846994e+12
#            2012  368802611.0  2.773270e+12
#            2011  361031820.0  2.497945e+12

# %%
world=world.stack().to_frame()
world
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08
#                 GDP         2.846994e+12
#            2012 Population  3.688026e+08
#                 GDP         2.773270e+12
#            2011 Population  3.610318e+08
#                 GDP         2.497945e+12
#            2010 Population  3.531122e+08
#                 GDP         2.103825e+12
#            2009 Population  3.450542e+08
#                 GDP         1.798878e+12
#            2008 Population  3.368865e+08
#                 GDP         2.081343e+12
#            2007 Population  3.287666e+08
#                 GDP         1.641666e+12
#            2006 Population  3.209067e+08
#                 GDP         1.404190e+12
#            2005 Population  3.134309e+08
# ...

# %%
world.loc[("Arab World"), 2015]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   """Entry point for launching an IPython kernel.
#                        0
# Population  3.920223e+08
# GDP         2.530102e+12

# %%
world.head()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08

# %%
world.unstack()
# Out:
#                            0
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
#             1965   9935358.0  1.006667e+09
#             1966  10148841.0  1.400000e+09
#             1967  10368600.0  1.673333e+09
#             1968  10599790.0  1.373333e+09
#             1969  10849510.0  1.408889e+09
#             1970  11121097.0  1.748887e+09
#             1971  11412821.0  1.831109e+09
#             1972  11716896.0  1.595555e+09
#             1973  12022514.0  1.733333e+09
#             1974  12315553.0  2.155555e+09
#             1975  12582954.0  2.366667e+09
#             1976  12831361.0  2.555556e+09
#             1977  13056499.0  2.953333e+09
#             1978  13222547.0  3.300000e+09
#             1979  13283279.0  3.697940e+09
# ...

# %%
world.unstack().unstack()
# Out:
#                                    0                              \
#                           Population
# year                            1960          1961          1962
# country
# Afghanistan             8.994793e+06  9.164945e+06  9.343772e+06
# Albania                          NaN           NaN           NaN
# Algeria                 1.112489e+07  1.140486e+07  1.169015e+07
# Andorra                          NaN           NaN           NaN
# Angola                           NaN           NaN           NaN
# Antigua and Barbuda              NaN           NaN           NaN
# Arab World                       NaN           NaN           NaN
# Argentina                        NaN           NaN  2.128768e+07
# Armenia                          NaN           NaN           NaN
# Aruba                            NaN           NaN           NaN
# Australia               1.027648e+07  1.048300e+07  1.074200e+07
# Austria                 7.047539e+06  7.086299e+06  7.129864e+06
# ...

# %%
world.unstack().unstack().unstack()
# Out:
#                year  country
# 0  Population  1960  Afghanistan               8.994793e+06
#                      Albania                            NaN
#                      Algeria                   1.112489e+07
#                      Andorra                            NaN
#                      Angola                             NaN
#                      Antigua and Barbuda                NaN
#                      Arab World                         NaN
#                      Argentina                          NaN
#                      Armenia                            NaN
#                      Aruba                              NaN
#                      Australia                 1.027648e+07
#                      Austria                   7.047539e+06
#                      Azerbaijan                         NaN
#                      Bahamas, The              1.095260e+05
#                      Bahrain                            NaN
# ...

# %%
world.head()
# Out:
#                                        0
# country    year
# Arab World 2015 Population  3.920223e+08
#                 GDP         2.530102e+12
#            2014 Population  3.842226e+08
#                 GDP         2.873600e+12
#            2013 Population  3.765043e+08

# %%
world.unstack(level='country')
# Out:
#                             0                                            \
# country           Afghanistan       Albania       Algeria       Andorra
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
#      GDP         5.466667e+08           NaN  2.001461e+09           NaN
# 1963 Population  9.531555e+06           NaN  1.198513e+07           NaN
#      GDP         7.511112e+08           NaN  2.703004e+09           NaN
# 1964 Population  9.728645e+06           NaN  1.229597e+07           NaN
#      GDP         8.000000e+08           NaN  2.909340e+09           NaN
# 1965 Population  9.935358e+06           NaN  1.262695e+07           NaN
# ...

# %%
world.unstack(level=2)
# Out:
#                            0
#                   Population           GDP
# country     year
# Afghanistan 1960   8994793.0  5.377778e+08
#             1961   9164945.0  5.488889e+08
#             1962   9343772.0  5.466667e+08
#             1963   9531555.0  7.511112e+08
#             1964   9728645.0  8.000000e+08
#             1965   9935358.0  1.006667e+09
#             1966  10148841.0  1.400000e+09
#             1967  10368600.0  1.673333e+09
#             1968  10599790.0  1.373333e+09
#             1969  10849510.0  1.408889e+09
#             1970  11121097.0  1.748887e+09
#             1971  11412821.0  1.831109e+09
#             1972  11716896.0  1.595555e+09
#             1973  12022514.0  1.733333e+09
#             1974  12315553.0  2.155555e+09
#             1975  12582954.0  2.366667e+09
#             1976  12831361.0  2.555556e+09
#             1977  13056499.0  2.953333e+09
#             1978  13222547.0  3.300000e+09
#             1979  13283279.0  3.697940e+09
# ...

# %%
world.unstack(level=0)
# Out:
#                             0                                            \
# country           Afghanistan       Albania       Algeria       Andorra
# year
# 1960 Population  8.994793e+06           NaN  1.112489e+07           NaN
#      GDP         5.377778e+08           NaN  2.723638e+09           NaN
# 1961 Population  9.164945e+06           NaN  1.140486e+07           NaN
#      GDP         5.488889e+08           NaN  2.434767e+09           NaN
# 1962 Population  9.343772e+06           NaN  1.169015e+07           NaN
#      GDP         5.466667e+08           NaN  2.001461e+09           NaN
# 1963 Population  9.531555e+06           NaN  1.198513e+07           NaN
#      GDP         7.511112e+08           NaN  2.703004e+09           NaN
# 1964 Population  9.728645e+06           NaN  1.229597e+07           NaN
#      GDP         8.000000e+08           NaN  2.909340e+09           NaN
# 1965 Population  9.935358e+06           NaN  1.262695e+07           NaN
# ...

# %%
world.unstack(level=1)
# Out:
#                                              0                              \
# year                                      1960          1961          1962
# country
# Afghanistan           Population  8.994793e+06  9.164945e+06  9.343772e+06
#                       GDP         5.377778e+08  5.488889e+08  5.466667e+08
# Albania               Population           NaN           NaN           NaN
#                       GDP                  NaN           NaN           NaN
# Algeria               Population  1.112489e+07  1.140486e+07  1.169015e+07
#                       GDP         2.723638e+09  2.434767e+09  2.001461e+09
# Andorra               Population           NaN           NaN           NaN
#                       GDP                  NaN           NaN           NaN
# Angola                Population           NaN           NaN           NaN
#                       GDP                  NaN           NaN           NaN
# ...

# %%
#Unstack year first, then unstack country column
world.unstack(level=[1,0])
# Out:
#                        0                                            \
# year                2015          2014          2013          2012
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
#                                                                     \
# year                2011          2010          2009          2008
# country       Arab World    Arab World    Arab World    Arab World
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
#                                             ...                     \
# year                2007          2006      ...               1969
# country       Arab World    Arab World      ...           Zimbabwe
# Population  3.287666e+08  3.209067e+08      ...       5.036321e+06
# ...

# %%
#Unstack country first, then unstack year column.
world.unstack(level=[0,1])
# Out:
#                        0                                            \
# country       Arab World
# year                2015          2014          2013          2012
# Population  3.920223e+08  3.842226e+08  3.765043e+08  3.688026e+08
# GDP         2.530102e+12  2.873600e+12  2.846994e+12  2.773270e+12
#
#                                                                     \
# country
# year                2011          2010          2009          2008
# Population  3.610318e+08  3.531122e+08  3.450542e+08  3.368865e+08
# GDP         2.497945e+12  2.103825e+12  1.798878e+12  2.081343e+12
#
#                                             ...                     \
# country                                     ...           Zimbabwe
# year                2007          2006      ...               1969
# Population  3.287666e+08  3.209067e+08      ...       5.036321e+06
# GDP         1.641666e+12  1.404190e+12      ...       1.747999e+09
#
# ...

# %%
world.unstack().unstack(fill_value=0)
# Out:
#                                    0                              \
#                           Population
# year                            1960          1961          1962
# country
# Afghanistan             8.994793e+06  9.164945e+06  9.343772e+06
# Albania                 0.000000e+00  0.000000e+00  0.000000e+00
# Algeria                 1.112489e+07  1.140486e+07  1.169015e+07
# Andorra                 0.000000e+00  0.000000e+00  0.000000e+00
# Angola                  0.000000e+00  0.000000e+00  0.000000e+00
# Antigua and Barbuda     0.000000e+00  0.000000e+00  0.000000e+00
# Arab World              0.000000e+00  0.000000e+00  0.000000e+00
# Argentina               0.000000e+00  0.000000e+00  2.128768e+07
# Armenia                 0.000000e+00  0.000000e+00  0.000000e+00
# Aruba                   0.000000e+00  0.000000e+00  0.000000e+00
# Australia               1.027648e+07  1.048300e+07  1.074200e+07
# Austria                 7.047539e+06  7.086299e+06  7.129864e+06
# ...

# %%
sales=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\salesmen.csv", parse_dates=["Date"])
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
len(sales)
# Out:
# 1830

# %%
sales["Salesman"].value_counts()
# Out:
# Ronald    366
# Jeb       366
# Bob       366
# Dave      366
# Oscar     366
# Name: Salesman, dtype: int64

# %%
sales.pivot(index="Date", columns="Salesman", values="Revenue")
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# 2016-01-06  1744  7859  8702   7794    5930
# 2016-01-07   918  8597  4250   9728    1933
# 2016-01-08  9863  3092  9719   5263    5709
# 2016-01-09  8337  1794  5614   7144    4707
# 2016-01-10  7543  7105   301   7663    8267
# 2016-01-11  1053  6851  9489   8888    1340
# 2016-01-12  4362  7147  8719   3092     279
# 2016-01-13  6812  6160  2349   6139    7540
# 2016-01-14  9047  7533  7690   5235    4214
# 2016-01-15  3594  9883  6917   5507    5346
# 2016-01-16  9800  3622   474   4947    9636
# 2016-01-17  7215  4565  8963   3325    6058
# 2016-01-18  7744  8246  2351   2611    3602
# 2016-01-19  9560  9229  5512   1905     316
# 2016-01-20  9863  8358  9509   6005    9352
# ...

# %%
sales.head(3)
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982

# %%
sales.pivot_table(values="Revenue",index="Salesman",aggfunc="mean")
# Out:
#               Revenue
# Salesman
# Bob       4992.292350
# Dave      5079.407104
# Jeb       5241.579235
# Oscar     4857.319672
# Ronald    4992.109290

# %%
sales.groupby("Salesman")["Revenue"].mean().to_frame()
# Out:
#               Revenue
# Salesman
# Bob       4992.292350
# Dave      5079.407104
# Jeb       5241.579235
# Oscar     4857.319672
# Ronald    4992.109290

# %%
foods=pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\foods.csv")
foods.head(3)
# Out:
#   First Name  Gender      City Frequency     Item  Spend
# 0      Wanda  Female  Stamford    Weekly   Burger  15.66
# 1       Eric    Male  Stamford     Daily  Chalupa  10.56
# 2    Charles    Male  New York     Never    Sushi  42.14

# %%
foods.pivot_table(index=["Gender","Item"], values="Spend", aggfunc="mean")
# Out:
#                       Spend
# Gender Item
# Female Burger     49.930488
#        Burrito    50.092000
#        Chalupa    54.635000
#        Donut      49.926316
#        Ice Cream  49.788519
#        Sushi      50.355699
# Male   Burger     49.613919
#        Burrito    48.344819
#        Chalupa    49.186761
#        Donut      43.649565
#        Ice Cream  51.096000
#        Sushi      55.614384

# %%
df = foods.pivot_table(index=["Gender","Item"], values = "Spend", aggfunc="max",columns="City")
df
# Out:
# City              New York  Philadelphia  Stamford
# Gender Item
# Female Burger        98.96         97.79     85.06
#        Burrito       92.25         96.79     99.21
#        Chalupa       98.43         99.29     98.78
#        Donut         95.63         96.52     91.75
#        Ice Cream     97.83         88.14     97.44
#        Sushi         99.51         99.02     95.43
# Male   Burger        90.32         99.68     97.20
#        Burrito       98.04         93.27     95.07
#        Chalupa       96.44         98.40     99.87
#        Donut         86.70         93.12     99.26
#        Ice Cream     97.65         99.24     99.17
#        Sushi         93.85         97.12     98.48

# %%
df = foods.pivot_table(index = ["Item"], values = "Spend", aggfunc = "max", columns = "City")
df
# Out:
# City       New York  Philadelphia  Stamford
# Item
# Burger        98.96         99.68     97.20
# Burrito       98.04         96.79     99.21
# Chalupa       98.43         99.29     99.87
# Donut         95.63         96.52     99.26
# Ice Cream     97.83         99.24     99.17
# Sushi         99.51         99.02     98.48

# %%
df.reset_index(inplace=True)
df
# Out:
# City       Item  New York  Philadelphia  Stamford
# 0        Burger     98.96         99.68     97.20
# 1       Burrito     98.04         96.79     99.21
# 2       Chalupa     98.43         99.29     99.87
# 3         Donut     95.63         96.52     99.26
# 4     Ice Cream     97.83         99.24     99.17
# 5         Sushi     99.51         99.02     98.48

# %%
df.melt(id_vars="Item")
# Out:
#          Item          City  value
# 0      Burger      New York  98.96
# 1     Burrito      New York  98.04
# 2     Chalupa      New York  98.43
# 3       Donut      New York  95.63
# 4   Ice Cream      New York  97.83
# 5       Sushi      New York  99.51
# 6      Burger  Philadelphia  99.68
# 7     Burrito  Philadelphia  96.79
# 8     Chalupa  Philadelphia  99.29
# 9       Donut  Philadelphia  96.52
# 10  Ice Cream  Philadelphia  99.24
# 11      Sushi  Philadelphia  99.02
# 12     Burger      Stamford  97.20
# 13    Burrito      Stamford  99.21
# 14    Chalupa      Stamford  99.87
# 15      Donut      Stamford  99.26
# 16  Ice Cream      Stamford  99.17
# 17      Sushi      Stamford  98.48

# %%
df=foods.pivot_table(index=["Item"], values="Spend",aggfunc="max",columns="City")
df
# Out:
# City       New York  Philadelphia  Stamford
# Item
# Burger        98.96         99.68     97.20
# Burrito       98.04         96.79     99.21
# Chalupa       98.43         99.29     99.87
# Donut         95.63         96.52     99.26
# Ice Cream     97.83         99.24     99.17
# Sushi         99.51         99.02     98.48

# %%
df.stack().to_frame().sort_values("City")
# Out:
#                             0
# Item      City
# Burger    New York      98.96
# Sushi     New York      99.51
# Burrito   New York      98.04
# Chalupa   New York      98.43
# Donut     New York      95.63
# Ice Cream New York      97.83
# Burger    Philadelphia  99.68
# Burrito   Philadelphia  96.79
# Chalupa   Philadelphia  99.29
# Sushi     Philadelphia  99.02
# Donut     Philadelphia  96.52
# Ice Cream Philadelphia  99.24
#           Stamford      99.17
# Chalupa   Stamford      99.87
# Burrito   Stamford      99.21
# Burger    Stamford      97.20
# Donut     Stamford      99.26
# Sushi     Stamford      98.48

# %%
import pandas as pd
fortune = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\fortune1000.csv", index_col = "Rank")
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
sectors = fortune.groupby("Sector")
sectors

# %%
sectors.groups.keys()
# Out:
# dict_keys(['Aerospace & Defense', 'Apparel', 'Business Services', 'Chemicals', 'Energy', 'Engineering & Construction', 'Financials', 'Food and Drug Stores', 'Food, Beverages & Tobacco', 'Health Care', 'Hotels, Resturants & Leisure', 'Household Products', 'Industrials', 'Materials', 'Media', 'Motor Vehicles & Parts', 'Retailing', 'Technology', 'Telecommunications', 'Transportation', 'Wholesalers'])

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
sectors.first().head(2)
# Out:
#                     Company               Industry       Location  Revenue  \
# Sector
# Aerospace & Defense  Boeing  Aerospace and Defense    Chicago, IL    96114
# Apparel                Nike                Apparel  Beaverton, OR    30601
#
#                      Profits  Employees
# Sector
# Aerospace & Defense     5176     161400
# Apparel                 3273      62600

# %%
fortune[fortune["Industry"] == "Aerospace & Defence"].head(2)
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
fortune[fortune["Sector"] == "Aerospace & Defence"].head(2)
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
fortune[fortune["Sector"] == "Aerospace & Defense"].head (2)
# Out:
#                   Company               Sector               Industry  \
# Rank
# 24                 Boeing  Aerospace & Defense  Aerospace and Defense
# 45    United Technologies  Aerospace & Defense  Aerospace and Defense
#
#             Location  Revenue  Profits  Employees
# Rank
# 24       Chicago, IL    96114     5176     161400
# 45    Farmington, CT    61047     7608     197200

# %%
fortune["Sector"].unique()
# Out:
# array(['Retailing', 'Energy', 'Technology', 'Financials', 'Health Care',
#        'Food and Drug Stores', 'Motor Vehicles & Parts',
#        'Telecommunications', 'Industrials', 'Aerospace & Defense',
#        'Household Products', 'Food, Beverages & Tobacco',
#        'Transportation', 'Media', 'Chemicals', 'Wholesalers', 'Apparel',
#        'Hotels, Resturants & Leisure', 'Materials', 'Business Services',
#        'Engineering & Construction'], dtype=object)

# %%
sectors.last().head(2)
# Out:
#                                    Company               Industry  \
# Sector
# Aerospace & Defense  Delta Tucker Holdings  Aerospace and Defense
# Apparel                              Guess                Apparel
#
#                             Location  Revenue  Profits  Employees
# Sector
# Aerospace & Defense       McLean, VA     1923     -133      12000
# Apparel              Los Angeles, CA     2204       82      13500

# %%
fortune[fortune["Sector"]=="Aerospace & Defence"].tail(1)
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...

# %%
sectors.get_group("Retailing").sort_values(by="Revenue", ascending=False).head(10)
# Out:
#              Company  Employees                      Industry  \
# Rank
# 1            Walmart    2300000         General Merchandisers
# 15            Costco     161000    Specialty Retailers: Other
# 28        Home Depot     385000    Specialty Retailers: Other
# 38            Target     341000         General Merchandisers
# 47            Lowe’s     225000    Specialty Retailers: Other
# 71          Best Buy     125000    Specialty Retailers: Other
# 89               TJX     216000  Specialty Retailers: Apparel
# 103           Macy’s     157500         General Merchandisers
# 111   Sears Holdings     178000         General Merchandisers
# 132          Staples      58963    Specialty Retailers: Other
#
#                  Location  Profits  Revenue
# Rank
# 1         Bentonville, AR    14694   482130
# 15           Issaquah, WA     2377   116199
# 28            Atlanta, GA     7009    88519
# 38        Minneapolis, MN     3363    73785
# 47        Mooresville, NC     2546    59074
# ...

# %%
fortune[fortune["Sector"]=="Retailing"]
# Out:
#                                Company     Sector  \
# Rank
# 1                              Walmart  Retailing
# 15                              Costco  Retailing
# 28                          Home Depot  Retailing
# 38                              Target  Retailing
# 47                              Lowe’s  Retailing
# 71                            Best Buy  Retailing
# 89                                 TJX  Retailing
# 103                             Macy’s  Retailing
# 111                     Sears Holdings  Retailing
# 132                            Staples  Retailing
# 136                         AutoNation  Retailing
# 139                     Dollar General  Retailing
# 143            Penske Automotive Group  Retailing
# 145                             Kohl’s  Retailing
# 177                                Gap  Retailing
# 180                        Dollar Tree  Retailing
# 191                             CarMax  Retailing
# 196                       Office Depot  Retailing
# ...

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
sectors.first().head(2)
# Out:
#                     Company               Industry       Location  Revenue  \
# Sector
# Aerospace & Defense  Boeing  Aerospace and Defense    Chicago, IL    96114
# Apparel                Nike                Apparel  Beaverton, OR    30601
#
#                      Profits  Employees
# Sector
# Aerospace & Defense     5176     161400
# Apparel                 3273      62600

# %%
fortune[fortune["Sector"] == "Aerospace & Defence"].head(2)
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
fortune[fortune["Sector"]=="Retailing"]
# Out:
#                                Company     Sector  \
# Rank
# 1                              Walmart  Retailing
# 15                              Costco  Retailing
# 28                          Home Depot  Retailing
# 38                              Target  Retailing
# 47                              Lowe’s  Retailing
# 71                            Best Buy  Retailing
# 89                                 TJX  Retailing
# 103                             Macy’s  Retailing
# 111                     Sears Holdings  Retailing
# 132                            Staples  Retailing
# 136                         AutoNation  Retailing
# 139                     Dollar General  Retailing
# 143            Penske Automotive Group  Retailing
# 145                             Kohl’s  Retailing
# 177                                Gap  Retailing
# 180                        Dollar Tree  Retailing
# 191                             CarMax  Retailing
# 196                       Office Depot  Retailing
# ...

# %%
sectors.sum()
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
sectors.count().head(10)
# Out:
#                             Company  Industry  Location  Revenue  Profits  \
# Sector
# Aerospace & Defense              20        20        20       20       20
# Apparel                          15        15        15       15       15
# Business Services                51        51        51       51       51
# Chemicals                        30        30        30       30       30
# Energy                          122       122       122      122      122
# Engineering & Construction       26        26        26       26       26
# Financials                      139       139       139      139      139
# Food and Drug Stores             15        15        15       15       15
# Food, Beverages & Tobacco        43        43        43       43       43
# Health Care                      75        75        75       75       75
#
#                             Employees
# Sector
# Aerospace & Defense                20
# Apparel                            15
# ...

# %%
sectors.mean()
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...

# %%
sectors.mean()[["Revenue"]]
# Out:
#                                    Revenue
# Sector
# Aerospace & Defense           17897.000000
# Apparel                        6397.866667
# Business Services              5337.156863
# Chemicals                      8129.900000
# Energy                        12441.057377
# Engineering & Construction     5922.423077
# Financials                    15950.784173
# Food and Drug Stores          32251.266667
# Food, Beverages & Tobacco     12929.465116
# Health Care                   21529.426667
# Hotels, Resturants & Leisure   6781.840000
# Household Products             8383.464286
# Industrials                   10816.978261
# Materials                      6026.627907
# Media                          8830.560000
# Motor Vehicles & Parts        20105.833333
# Retailing                     18313.450000
# Technology                    13505.882353
# Telecommunications            30788.933333
# Transportation                11347.444444
# Wholesalers                   11120.000000

# %%
sectors.max()["Revenue"]
# Out:
# Sector
# Aerospace & Defense              96114
# Apparel                          30601
# Business Services                19330
# Chemicals                        48778
# Energy                          246204
# Engineering & Construction       18114
# Financials                      210821
# Food and Drug Stores            153290
# Food, Beverages & Tobacco        67702
# Health Care                     181241
# Hotels, Resturants & Leisure     25413
# Household Products               78756
# Industrials                     140389
# Materials                        22534
# Media                            52465
# Motor Vehicles & Parts          152356
# Retailing                       482130
# Technology                      233715
# Telecommunications              146801
# Transportation                   58363
# Wholesalers                      48681
# Name: Revenue, dtype: int64

# %%
sectors.max()["Profits"]
# Out:
# Sector
# Aerospace & Defense              7608
# Apparel                          3273
# Business Services                6328
# Chemicals                        7685
# Energy                          16150
# Engineering & Construction        803
# Financials                      24442
# Food and Drug Stores             5237
# Food, Beverages & Tobacco        7351
# Health Care                     18108
# Hotels, Resturants & Leisure     5920
# Household Products               7036
# Industrials                      4833
# Materials                         991
# Media                            8382
# Motor Vehicles & Parts           9687
# Retailing                       14694
# Technology                      53394
# Telecommunications              17879
# Transportation                   7610
# Wholesalers                      1472
# Name: Profits, dtype: int64

# %%
sectors[["Profits"]].max()
# Out:
#                               Profits
# Sector
# Aerospace & Defense              7608
# Apparel                          3273
# Business Services                6328
# Chemicals                        7685
# Energy                          16150
# Engineering & Construction        803
# Financials                      24442
# Food and Drug Stores             5237
# Food, Beverages & Tobacco        7351
# Health Care                     18108
# Hotels, Resturants & Leisure     5920
# Household Products               7036
# Industrials                      4833
# Materials                         991
# Media                            8382
# Motor Vehicles & Parts           9687
# Retailing                       14694
# Technology                      53394
# Telecommunications              17879
# Transportation                   7610
# Wholesalers                      1472

# %%
sectors["Revenue"].min()
# Out:
# Sector
# Aerospace & Defense             1923
# Apparel                         2204
# Business Services               1910
# Chemicals                       2084
# Energy                          1898
# Engineering & Construction      1909
# Financials                      1902
# Food and Drug Stores            2151
# Food, Beverages & Tobacco       2066
# Health Care                     1987
# Hotels, Resturants & Leisure    1896
# Household Products              1914
# Industrials                     1895
# Materials                       1924
# Media                           1921
# Motor Vehicles & Parts          1986
# Retailing                       1999
# Technology                      1920
# Telecommunications              2726
# Transportation                  1995
# Wholesalers                     1917
# Name: Revenue, dtype: int64

# %%
multiple = fortune.groupby(["Sector","Industry"])
multiple

# %%
multiple.sum()
# Out:
#                                                                            Revenue  \
# Sector                     Industry
# Aerospace & Defense        Aerospace and Defense                            357940
# Apparel                    Apparel                                           95968
# Business Services          Advertising, marketing                            22748
#                            Diversified Outsourcing Services                  64829
#                            Education                                          7485
#                            Financial Data Services                          100778
#                            Miscellaneous                                     11185
#                            Temporary Help                                    34716
#                            Waste Management                                  30454
# Chemicals                  Chemicals                                        243897
# ...

# %%
sectors.agg({
    "Revenue": "sum",
    "Profits": "sum",
    "Employees": "mean"
})
# Out:
#                               Revenue  Profits     Employees
# Sector
# Aerospace & Defense            357940    28742  48402.850000
# Apparel                         95968     8236  23093.133333
# Business Services              272195    28227  26687.254902
# Chemicals                      243897    22628  15455.033333
# Energy                        1517809   -73447   9745.303279
# Engineering & Construction     153983     5304  15642.615385
# Financials                    2217159   260209  24172.287770
# Food and Drug Stores           483769    16759  93026.533333
# Food, Beverages & Tobacco      555967    51417  28177.488372
# Health Care                   1614707   106114  35710.520000
# Hotels, Resturants & Leisure   169546    20697  99369.800000
# Household Products             234737    14428  23072.785714
# Industrials                    497581    20764  33591.934783
# Materials                      259145     4428  14840.069767
# ...

# %%
sectors.agg(["sum","mean","size"])
# Out:
#                               Revenue                    Profits               \
#                                   sum          mean size     sum         mean
# Sector
# Aerospace & Defense            357940  17897.000000   20   28742  1437.100000
# Apparel                         95968   6397.866667   15    8236   549.066667
# Business Services              272195   5337.156863   51   28227   553.470588
# Chemicals                      243897   8129.900000   30   22628   754.266667
# Energy                        1517809  12441.057377  122  -73447  -602.024590
# Engineering & Construction     153983   5922.423077   26    5304   204.000000
# Financials                    2217159  15950.784173  139  260209  1872.007194
# Food and Drug Stores           483769  32251.266667   15   16759  1117.266667
# Food, Beverages & Tobacco      555967  12929.465116   43   51417  1195.744186
# Health Care                   1614707  21529.426667   75  106114  1414.853333
# ...

# %%
sectors.agg({
    "Revenue": ["sum","size"],
    "Profits": "sum",
    "Employees": "mean"
})
# Out:
#                               Revenue      Profits     Employees
#                                   sum size     sum          mean
# Sector
# Aerospace & Defense            357940   20   28742  48402.850000
# Apparel                         95968   15    8236  23093.133333
# Business Services              272195   51   28227  26687.254902
# Chemicals                      243897   30   22628  15455.033333
# Energy                        1517809  122  -73447   9745.303279
# Engineering & Construction     153983   26    5304  15642.615385
# Financials                    2217159  139  260209  24172.287770
# Food and Drug Stores           483769   15   16759  93026.533333
# Food, Beverages & Tobacco      555967   43   51417  28177.488372
# Health Care                   1614707   75  106114  35710.520000
# Hotels, Resturants & Leisure   169546   25   20697  99369.800000
# Household Products             234737   28   14428  23072.785714
# ...

# %%
df = pd.DataFrame(columns=fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for sector, data in sectors:
    highest = data.nlargest(1,"Revenue")
    df = df.append(highest)
df.head(10)
# Out:
#                     Company                      Sector  \
# 24                   Boeing         Aerospace & Defense
# 91                     Nike                     Apparel
# 144           ManpowerGroup           Business Services
# 56             Dow Chemical                   Chemicals
# 2               Exxon Mobil                      Energy
# 155                   Fluor  Engineering & Construction
# 4        Berkshire Hathaway                  Financials
# 7                CVS Health        Food and Drug Stores
# 41   Archer Daniels Midland   Food, Beverages & Tobacco
# 5                  McKesson                 Health Care
#
#                                      Industry           Location Revenue  \
# 24                      Aerospace and Defense        Chicago, IL   96114
# 91                                    Apparel      Beaverton, OR   30601
# 144                            Temporary Help      Milwaukee, WI   19330
# ...

# %%
fortune.sort_values("Revenue", ascending=False).head(10)
# Out:
#                  Company                  Sector  \
# Rank
# 1                Walmart               Retailing
# 2            Exxon Mobil                  Energy
# 3                  Apple              Technology
# 4     Berkshire Hathaway              Financials
# 5               McKesson             Health Care
# 6     UnitedHealth Group             Health Care
# 7             CVS Health    Food and Drug Stores
# 8         General Motors  Motor Vehicles & Parts
# 9             Ford Motor  Motor Vehicles & Parts
# 10                  AT&T      Telecommunications
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# ...

# %%
fortune.sort_values("Revenue", ascending=True).head(10)
# Out:
#                          Company                        Sector  \
# Rank
# 1000           Briggs & Stratton                   Industrials
# 999                      Wendy’s  Hotels, Resturants & Leisure
# 997    Portland General Electric                        Energy
# 997    Portland General Electric                        Energy
# 996   New York Community Bancorp                    Financials
# 995                    EP Energy                        Energy
# 994                 MDC Holdings    Engineering & Construction
# 993        DeVry Education Group             Business Services
# 992                       Revlon            Household Products
# 991            BlueLinx Holdings                   Wholesalers
#
#                              Industry           Location  Revenue  Profits  \
# Rank
# 1000             Industrial Machinery      Wauwatosa, WI     1895       46
# 999                     Food Services         Dublin, OH     1896      161
# ...

# %%
import pandas as pd

# %%
week1 = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\Restaurant - Week 1 Sales.csv")
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2 = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\Restaurant - Week 2 Sales.csv")
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
food = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\Restaurant - Foods.csv")
food.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
customers = pd.read_csv("C:\\Users\\student\\Downloads\\OneDrive_1_11-4-2019\\Python Modules\\data\\Restaurant - Customers.csv")
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
len(pd.concat([week1,week2]))
# Out:
# 500

# %%
pd.concat([week1,week2])
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 220          495        2
# 221          794        6
# 222          734       10
# ...

# %%
df = pd.concat([week1,week2], ignore_index=True)
df
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# ...

# %%
pd.concat([week1,week2],ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# ..           ...      ...
# 470          495        2
# 471          794        6
# 472          734       10
# ...

# %%
sales = pd.concat([week1,week2], keys = ["Week 1","Week 2"])
sales
# Out:
#             Customer ID  Food ID
# Week 1 0            537        9
#        1             97        4
#        2            658        1
#        3            202        2
#        4            155        9
#        5            213        8
#        6            600        1
#        7            503        5
#        8             71        3
#        9            174        3
#        10           961        9
#        11           966        5
#        12           641        4
#        13           288        2
#        14           149        4
#        15           954        2
#        16           147        9
#        17           155        1
#        18           550        6
#        19           101        7
#        20           549        6
#        21            75        6
#        22            78        7
#        23           514        5
#        24           833        7
#        25           329        8
#        26           586       10
# ...

# %%
sales.loc[("Week 2", 249)]
# Out:
# Customer ID    249
# Food ID          6
# Name: (Week 2, 249), dtype: int64

# %%
week1.append(week2, ignore_index=True).head(15)
# Out:
#     Customer ID  Food ID
# 0           537        9
# 1            97        4
# 2           658        1
# 3           202        2
# 4           155        9
# 5           213        8
# 6           600        1
# 7           503        5
# 8            71        3
# 9           174        3
# 10          961        9
# 11          966        5
# 12          641        4
# 13          288        2
# 14          149        4

# %%
week1.append(week2, ignore_index=True).head(15)
# Out:
#     Customer ID  Food ID
# 0           537        9
# 1            97        4
# 2           658        1
# 3           202        2
# 4           155        9
# 5           213        8
# 6           600        1
# 7           503        5
# 8            71        3
# 9           174        3
# 10          961        9
# 11          966        5
# 12          641        4
# 13          288        2
# 14          149        4

# %%
import pandas as pd
from pandas_datareader import data

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-248b4ec97936> in <module>
#       1 import pandas as pd
# ----> 2 from pandas_datareader import data
#       3
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
import pandas as pd

# %%
week1 = pd.read_csv("Python Modules\\data\\Restaurant - Week 1 Sales.csv")
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week1
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          413        9
# 246          926        6
# 247          134        3
# 248          396        6
# 249          535       10
#
# [250 rows x 2 columns]

# %%
print("love love")
# Out:
# love love

# %%
purePyWeek1 = [[537,9], [97,4]]

# %%
purePyWeek1
# Out:
# [[537, 9], [97, 4]]

# %%
nba = pd.read_csv("Python Modules\\data\\nba.csv",index_col="Name")

# %%
nba.loc['Kobe Bryant']
# Out:
# Team        Los Angeles Lakers
# Number                      24
# Position                    SF
# Age                         37
# Height                     6-6
# Weight                     212
# College                    NaN
# Salary                 2.5e+07
# Name: Kobe Bryant, dtype: object

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, Avery Bradley to nan
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Team      457 non-null    object
#  1   Number    457 non-null    float64
#  2   Position  457 non-null    object
#  3   Age       457 non-null    float64
#  4   Height    457 non-null    object
#  5   Weight    457 non-null    float64
#  6   College   373 non-null    object
#  7   Salary    446 non-null    float64
# dtypes: float64(4), object(4)
# memory usage: 32.2+ KB

# %%
nba.columns.get_loc("Team")
# Out:
# 0
